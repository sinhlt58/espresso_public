# %%
import numpy as np
import pickle
import json
from sklearn.cluster import MeanShift, DBSCAN, Birch

# %%
from_date = '2019-05-01'
to_date = '2019-05-10'
domains = [
    'Thế giới',
    'Thể thao',
    'Kinh doanh',
    'Xã hội',
    'Chính trị',
    'Giáo dục',
    'Pháp luật',
    'Khoa học',
    'all'
]
algs = ['mean_shift', 'dbscan', 'birch']

# %%
def print_doc(doc, fields):
    source = doc['_source']

    for field in fields:
        if field in source:
            print ('{}: {}'.format(field, source[field]))
    
def report_model(model_file, docs_file):
    model = pickle.load(open(model_file, 'rb'))
    with open(docs_file, 'r', encoding='utf-8') as f:
        docs = json.load(f)
    
    label_count = {}
    labels = model.labels_.tolist()
    
    for idx, label in enumerate(labels):
        if not label in label_count:
            label_count[label] = [idx]
        else:
            label_count[label].append(idx)
    
    # sort label count
    count_pair = []
    for label, idxes in label_count.items():
        count_pair.append((label, len(idxes)))

    count_pair.sort(key=lambda p: -p[1])
    
    for label, count in count_pair[1:5]:
        if not label == -1:
            print ('Label {} has {} articles'.format(label, count))
            for idx in label_count[label]:
                print_doc(docs[idx], ['title'])

# %%
PREFIX = '/media/sinhblack/Media1/works/article_research/'
for domain in domains:
    for alg in algs:
        model_file = '{}data/models/{}_{}_{}_{}.pkl'.format(PREFIX, domain, from_date, to_date, alg)
        docs_file = '{}data/by_domain/{}_{}_{}.json'.format(PREFIX, domain.replace(' ', '_'), from_date, to_date)
        
        print ('###### START -> DOMAIN: {}, ALGORITHM: {} <- ######'.format(domain, alg))
        report_model(model_file, docs_file)
        print ('###### END -> DOMAIN: {}, ALGORITHM: {} <- ######'.format(domain, alg))
# Out:
# ###### START -> DOMAIN: Thế giới, ALGORITHM: mean_shift <- ######
# Label 1 has 12 articles
# title: Mỹ để ngỏ khả năng can thiệp quân sự vào Venezuela sau đảo chính bất thành
# title: Xe bọc thép Trung Quốc sản xuất xuất hiện trong cuộc bạo động tại Venezuela
# title: Tổng thống Venezuela chúc mừng quân đội đánh bại âm mưu đảo chính của phe đối lập
# title: Cánh cửa hẹp cho phe đối lập sau đảo chính bất thành tại Venezuela
# title: “Dấu chân” của Mỹ trong kế hoạch đảo chính bất thành tại Venezuela
# title: Tổng thống Venezuela hô hào quân đội đánh bại 'kẻ chủ mưu đảo chính'
# title: Lộ kế hoạch 5.000 lính đánh thuê lật đổ ông Maduro
# title: Cảnh tượng hỗn loạn như chiến trường tại Venezuela sau âm mưu đảo chính
# title: Mỹ tìm cách rót tiền cho thủ lĩnh đối lập để lật đổ tổng thống Venezuela
# title: Phản ứng trái chiều của các nước về đảo chính Venezuela
# title: Hé lộ nguyên nhân khiến cuộc đảo chính tại Venezuela đổ vỡ vào phút chót
# title: Tổng thống Venezuela tuyên bố không bỏ trốn sang Cuba
# Label 2 has 2 articles
# title: Tổng bí thư, Chủ tịch nước thăm hỏi Nga sau vụ máy bay bốc cháy
# title: Nữ tiếp viên Nga đạp cửa cứu hành khách khỏi máy bay bốc cháy
# Label 3 has 2 articles
# title: Công nương Anh Meghan và Hoàng tử Harry đón con trai đầu lòng
# title: Nàng dâu "Tây" thêm một lần phá vỡ truyền thống của hoàng gia Anh
# Label 192 has 2 articles
# title: Chuyên gia “giải mã” vụ phóng tên lửa mới của Triều Tiên
# title: Mỹ vẫn duy trì phương án quân sự nếu ngoại giao thất bại với Triều Tiên
# ###### END -> DOMAIN: Thế giới, ALGORITHM: mean_shift <- ######
# ###### START -> DOMAIN: Thế giới, ALGORITHM: dbscan <- ######
# Label 1 has 2 articles
# title: Boeing 737 chở 143 người lao xuống sông ở Mỹ
# title: Hành khách kể phút kinh hoàng khi Boeing 737 lao xuống sông
# Label 2 has 2 articles
# title: Tổng bí thư, Chủ tịch nước thăm hỏi Nga sau vụ máy bay bốc cháy
# title: Nữ tiếp viên Nga đạp cửa cứu hành khách khỏi máy bay bốc cháy
# Label 3 has 2 articles
# title: Nỗ lực hạ cánh khẩn bất thành của máy bay Nga trước khi bốc cháy
# title: Diễn biến vụ máy bay Nga bốc cháy khi hạ cánh khẩn cấp
# ###### END -> DOMAIN: Thế giới, ALGORITHM: dbscan <- ######
# ###### START -> DOMAIN: Thế giới, ALGORITHM: birch <- ######
# Label 268 has 4 articles
# title: Venezuela ra trát bắt giữ thủ lĩnh tinh thần của phe đối lập sau đảo chính bất thành
# title: Rơi trực thăng quân sự Venezuela, 7 người thiệt mạng
# title: Tổng thống Venezuela kêu gọi đối thoại để "sửa chữa sai lầm"
# title: Nga bác tin bàn bạc đưa Tổng thống Venezuela ra nước ngoài giữa lúc căng thẳng
# Label 11 has 3 articles
# title: Mỹ để ngỏ khả năng can thiệp quân sự vào Venezuela sau đảo chính bất thành
# title: Xe bọc thép Trung Quốc sản xuất xuất hiện trong cuộc bạo động tại Venezuela
# title: Lộ kế hoạch 5.000 lính đánh thuê lật đổ ông Maduro
# Label 21 has 3 articles
# title: Sứ mệnh lớn lao của tân Quốc vương Thái Lan
# title: Quốc vương Thái Lan ngồi kiệu dát vàng 16 người khiêng trong lễ rước đăng quang
# title: Quốc vương Thái Lan tuyên bố trị vì bằng chính nghĩa ngay sau đăng quang
# Label 103 has 3 articles
# title: Nhân chứng vụ rơi máy bay Nga: Máy bay cháy rực như ngọn đuốc
# title: Khoảnh khắc máy bay Nga chở 78 người lao xuống đường băng, bốc cháy
# title: Bên trong máy bay Nga cháy ngùn ngụt khi hạ cánh
# ###### END -> DOMAIN: Thế giới, ALGORITHM: birch <- ######
# ###### START -> DOMAIN: Thể thao, ALGORITHM: mean_shift <- ######
# Label 1 has 13 articles
# title: Filip Nguyễn hứa sẽ ghi điểm trong mắt HLV Park Hang Seo
# title: Alexander Đặng sẽ làm tất cả để được khoác áo đội tuyển Việt Nam
# title: HLV Park Hang Seo chốt ngày sang châu Âu “xem giò” cầu thủ Việt kiều
# title: HLV Park Hang-seo sẽ trực tiếp theo dõi bốn cầu thủ Việt kiều
# title: HLV Park Hang Seo tiết lộ danh sách cầu thủ Việt kiều trong tầm ngắm
# title: Người đại diện Alexander Đặng sẵn sàng làm tài xế cho HLV Park Hang Seo
# title: Các cựu binh đội tuyển Việt Nam ghi điểm trong mắt thầy Park
# title: Alexander Đặng mờ nhạt trong ngày HLV Park Hang Seo “xem giò”
# title: Cầu thủ Việt kiều Hà Lan được HLV Park Hang Seo quan tâm là ai?
# title: Bóng đá Việt Nam và giấc mơ World Cup
# title: HLV Park Hang Seo sang châu Âu "xem giò" cầu thủ Việt kiều
# title: HLV Park Hang Seo bất ngờ huỷ kế hoạch gặp Filip Nguyễn
# title: Alexander Đặng khó lọt vào mắt xanh của HLV Park Hang Seo
# Label 2 has 5 articles
# title: HLV Park Hang Seo: “HCV SEA Games là một thách thức lớn”
# title: HLV đồng hương tạm thay Park Hang-seo dẫn dắt U23 Việt Nam
# title: Dàn trợ lý Hàn Quốc có giúp thầy Park giành HCV SEA Games?
# title: U23 Việt Nam sẽ có thầy mới người Hàn Quốc
# title: HLV Kim Han-yoon đủ năng lực và danh tiếng để cầm quân ở U23 Việt Nam?
# Label 34 has 2 articles
# title: 3 nguyên nhân có thể khiến Man Utd chia tay De Gea
# title: 10 ứng viên cho vị trí Giám đốc kỹ thuật đầu tiên của Man Utd
# Label 7 has 2 articles
# title: Tottenham 0-1 Ajax: Pha làm bàn của Van de Beek
# title: Nhìn lại chiến thắng ngọt ngào của Ajax trên sân Tottenham
# ###### END -> DOMAIN: Thể thao, ALGORITHM: mean_shift <- ######
# ###### START -> DOMAIN: Thể thao, ALGORITHM: dbscan <- ######
# ###### END -> DOMAIN: Thể thao, ALGORITHM: dbscan <- ######
# ###### START -> DOMAIN: Thể thao, ALGORITHM: birch <- ######
# Label 79 has 3 articles
# title: Cầu thủ B.Bình Dương chấn thương nặng được trọng tài cấp cứu ngay trên sân
# title: Chelsea 3-0 Watford: The Blues vào top 3
# title: Đội tuyển Việt Nam khủng hoảng trung phong: Thầy Park nhắm đến Alexander Đặng?
# Label 71 has 2 articles
# title: Emery vô tình làm lộ chiến thuật của Arsenal tại Europa League
# title: Emery: 'Arsenal cần quên Ngoại hạng Anh, tập trung cho Europa League'
# Label 73 has 2 articles
# title: Ramsey rơi nước mắt trong ngày chia tay Arsenal
# title: Arsenal xác nhận chia tay “chân gỗ” Welbeck
# Label 118 has 2 articles
# title: Guardiola bất ngờ khi Man City có gần 100 điểm mùa này
# title: Guardiola: 'Liverpool không sụp đổ vì thua Barca'
# ###### END -> DOMAIN: Thể thao, ALGORITHM: birch <- ######
# ###### START -> DOMAIN: Kinh doanh, ALGORITHM: mean_shift <- ######
# Label 1 has 5 articles
# title: Người dùng Mỹ quan tâm điều gì khi mua thủy sản Việt Nam
# title: Vietjet đề xuất xây sân bay, Vingroup muốn hút người tài về nước
# title: Chủ tịch Vietjet kiến nghị tư nhân tham gia đầu tư hạ tầng sân bay
# title: Vingroup, TH Truemilk, Trường Hải "hiến kế" cho Chính phủ phát triển kinh tế tư nhân
# title: Hành trình NS BlueScope đồng hành cùng ngành thép Việt
# Label 2 has 4 articles
# title: Thủ tướng chỉ đạo làm rõ việc tăng giá điện
# title: Bộ Công Thương sẽ kiểm tra tác động tăng giá điện
# title: Bộ Công Thương lập 3 đoàn kiểm tra liên quan đến việc tăng giá điện
# title: Phó thủ tướng yêu cầu tiếp tục theo dõi tác động tăng giá điện
# Label 3 has 4 articles
# title: Trump tuyên bố tăng gấp đôi thuế với hàng Trung Quốc
# title: Chứng khoán Mỹ đi xuống vì Trump muốn tăng thuế với Trung Quốc
# title: Mỹ tăng sức ép để đạt thỏa thuận thương mại với Trung Quốc
# title: Trung Quốc có thể hoãn đàm phán thương mại với Mỹ
# Label 4 has 3 articles
# title: Giá USD bật tăng mạnh
# title: Tỷ giá USD/VND tiếp tục sụt giảm
# title: Mua thêm 8,35 tỷ USD, tỷ giá trung tâm đạt mức cao kỷ lục
# ###### END -> DOMAIN: Kinh doanh, ALGORITHM: mean_shift <- ######
# ###### START -> DOMAIN: Kinh doanh, ALGORITHM: dbscan <- ######
# Label 3 has 4 articles
# title: Giá vàng miếng bật tăng theo thế giới vì căng thẳng Mỹ - Trung
# title: Giá vàng bật tăng phiên cuối tuần
# title: Giá vàng miếng tăng theo thế giới
# title: Giá vàng miếng giảm cả trăm nghìn đồng mỗi lượng
# Label 1 has 3 articles
# title: Giá USD bật tăng mạnh
# title: Tỷ giá USD/VND tiếp tục sụt giảm
# title: Mua thêm 8,35 tỷ USD, tỷ giá trung tâm đạt mức cao kỷ lục
# Label 2 has 2 articles
# title: TPHCM: Đề xuất thu thuế với các sản phẩm của hàng triệu phụ nữ
# title: Đề xuất thu thuế tiêu thụ đặc biệt với điện thoại di động, nước hoa, dịch vụ thẩm mỹ
# ###### END -> DOMAIN: Kinh doanh, ALGORITHM: dbscan <- ######
# ###### START -> DOMAIN: Kinh doanh, ALGORITHM: birch <- ######
# Label 192 has 3 articles
# title: Giá vàng miếng bật tăng theo thế giới vì căng thẳng Mỹ - Trung
# title: Giá vàng miếng tăng theo thế giới
# title: Giá vàng miếng giảm cả trăm nghìn đồng mỗi lượng
# Label 43 has 2 articles
# title: TPHCM: Đề xuất thu thuế với các sản phẩm của hàng triệu phụ nữ
# title: Đề xuất thu thuế tiêu thụ đặc biệt với điện thoại di động, nước hoa, dịch vụ thẩm mỹ
# Label 15 has 1 articles
# title: “Ông chủ” doanh nghiệp thủy sản trúng số độc đắc gần 120 tỷ đồng
# Label 56 has 1 articles
# title: Tuyệt phẩm cây cảnh cứ đụng vào là tỏa hương, giá bán tới 2 tỷ đồng
# ###### END -> DOMAIN: Kinh doanh, ALGORITHM: birch <- ######
# ###### START -> DOMAIN: Xã hội, ALGORITHM: mean_shift <- ######
# Label 79 has 1 articles
# title: Công bố thanh tra toàn diện Khu Liên hợp thể thao quốc gia Mỹ Đình
# Label 76 has 1 articles
# title: Hai du khách tố bị đánh vỡ đầu vì phản ứng chuyện "chặt chém"
# Label 52 has 1 articles
# title: Nghi án nghịch tử dùng búa hành hung cha, bị cha đánh vỡ đầu
# Label 35 has 1 articles
# title: Văn hóa rượu bia quá dễ dãi gây nên vấn nạn tài xế “ma men”!
# ###### END -> DOMAIN: Xã hội, ALGORITHM: mean_shift <- ######
# ###### START -> DOMAIN: Xã hội, ALGORITHM: dbscan <- ######
# Label 0 has 31 articles
# title: Hà Nội: Nghi vấn xe biển xanh tông tài xế xe ôm bị thương rồi bỏ chạy
# title: Lốc xoáy cuốn rạp đám cưới treo lên dây điện, cả khu mất điện
# title: Linh xa chở linh cữu Đại tướng Lê Đức Anh qua các tuyến phố Hà Nội
# title: Người dân "tay xách nách mang" trở lại Thủ đô sau nghỉ lễ
# title: 5 căn nhà cháy rụi nghi do nổ bình gas
# title: TPHCM: Hạn chế lưu thông nhiều tuyến đường phục vụ lễ Quốc tang
# title: Đại tướng Lê Đức Anh và những phút sinh tử trên trận mạc
# title: Kính cẩn, xúc động đón linh cữu Đại tướng Lê Đức Anh về đến Sài Gòn
# title: 96 người chết vì tai nạn giao thông trong 5 ngày nghỉ lễ
# title: Đại tướng Lê Đức Anh và bức thư gỡ "nút thắt" cho du học sinh
# title: TPHCM lên kế hoạch tổ chức lễ viếng, truy điệu và an táng Đại tướng Lê Đức Anh
# title: Đà Nẵng tạm dừng hoạt động cảng sông Hàn
# title: Hơn 100 nhà dân nứt toác do thi công quốc lộ
# title: Nhóm người lạ đập phá tan hoang quán ăn bị tố “chặt chém”, hành hung khách
# title: Vụ 7 năm xử lý rác phát hiện 300 xác thai nhi: Kiểm tra mẫu vật trong 9 hũ sành
# title: Phát hiện thi thể Phó Giám đốc Trung tâm Giám định pháp y tại nhà riêng
# title: Xe khách bốc cháy dữ dội trong đêm, 30 hành khách chạy thoát thân
# title: Chiến sỹ Điện Biên kể chuyện
# title: Long An: Chủ quán đánh toác đầu khách đã dọn đồ về quê
# title: Cháy nhà chứa hàng hóa, một phụ nữ tử vong
# title: Người dân Biên Hòa bì bõm lội nước sau cơn mưa lớn đầu mùa
# title: Xử lý nghiêm các tàu cá khai thác hải sản bất hợp pháp
# title: Tăng giá điện 2019: Hãy là người tiêu dùng thông minh
# title: Cháy lớn trong khu dân cư, nhiều người may mắn thoát nạn
# title: Hà Nội phân luồng giao thông phục vụ Quốc tang nguyên Chủ tịch nước Lê Đức Anh
# title: Cá chết, rác thải lại nổi đầy các kênh nước ở Đà Nẵng
# title: Cảng cá vừa nạo vét đã bị bồi lấp trở lại, ngư dân khóc ròng
# title: Tài xế Mercedes tông chết 2 phụ nữ ở hầm Kim Liên có nồng độ cồn tới 0,751 mg
# title: Hà Nội: Bắt xe khách 29 chỗ nhồi… 73 người
# title: Rủ nhau ra lòng hồ chơi, 2 học sinh bị đuối nước
# title: Sư thầy phát hoảng phát hiện người đàn ông treo cổ trong chùa
# ###### END -> DOMAIN: Xã hội, ALGORITHM: dbscan <- ######
# ###### START -> DOMAIN: Xã hội, ALGORITHM: birch <- ######
# Label 9 has 1 articles
# title: Công bố thanh tra toàn diện Khu Liên hợp thể thao quốc gia Mỹ Đình
# Label 15 has 1 articles
# title: Hai du khách tố bị đánh vỡ đầu vì phản ứng chuyện "chặt chém"
# Label 85 has 1 articles
# title: Nghi án nghịch tử dùng búa hành hung cha, bị cha đánh vỡ đầu
# Label 72 has 1 articles
# title: Văn hóa rượu bia quá dễ dãi gây nên vấn nạn tài xế “ma men”!
# ###### END -> DOMAIN: Xã hội, ALGORITHM: birch <- ######
# ###### START -> DOMAIN: Chính trị, ALGORITHM: mean_shift <- ######
# Label 15 has 1 articles
# title: Máy bay đưa nguyên Chủ tịch nước Lê Đức Anh về nơi an nghỉ cuối cùng tại TPHCM
# Label 2 has 1 articles
# title: 2.000 người sẽ tham dự chương trình "Huyền thoại một con đường"
# Label 28 has 1 articles
# title: Kết luận về sai phạm của 1 nguyên Phó Thủ tướng, 1 Bộ trưởng, 5 Thứ trưởng
# Label 10 has 1 articles
# title: Lời cảm ơn của Ban Lễ tang và gia đình nguyên Chủ tịch nước, Đại tướng Lê Đức Anh
# ###### END -> DOMAIN: Chính trị, ALGORITHM: mean_shift <- ######
# ###### START -> DOMAIN: Chính trị, ALGORITHM: dbscan <- ######
# Label 0 has 6 articles
# title: Máy bay đưa nguyên Chủ tịch nước Lê Đức Anh về nơi an nghỉ cuối cùng tại TPHCM
# title: Lời cảm ơn của Ban Lễ tang và gia đình nguyên Chủ tịch nước, Đại tướng Lê Đức Anh
# title: Chủ tịch nước Lê Đức Anh - Nhà lãnh đạo có tầm nhìn, quyết đoán
# title: Đông đảo lãnh đạo, nhân dân miền Nam đến tiễn đưa nguyên Chủ tịch nước Lê Đức Anh
# title: Lễ an táng Đại tướng, nguyên Chủ tịch nước Lê Đức Anh
# title: Nghi thức treo cờ rủ Lễ Quốc tang Đại tướng Lê Đức Anh
# ###### END -> DOMAIN: Chính trị, ALGORITHM: dbscan <- ######
# ###### START -> DOMAIN: Chính trị, ALGORITHM: birch <- ######
# Label 1 has 1 articles
# title: Máy bay đưa nguyên Chủ tịch nước Lê Đức Anh về nơi an nghỉ cuối cùng tại TPHCM
# Label 2 has 1 articles
# title: 2.000 người sẽ tham dự chương trình "Huyền thoại một con đường"
# Label 3 has 1 articles
# title: Kết luận về sai phạm của 1 nguyên Phó Thủ tướng, 1 Bộ trưởng, 5 Thứ trưởng
# Label 4 has 1 articles
# title: Lời cảm ơn của Ban Lễ tang và gia đình nguyên Chủ tịch nước, Đại tướng Lê Đức Anh
# ###### END -> DOMAIN: Chính trị, ALGORITHM: birch <- ######
# ###### START -> DOMAIN: Giáo dục, ALGORITHM: mean_shift <- ######
# Label 1 has 5 articles
# title: Chính xác, ông là Michael Faraday
# title: Chưa chính xác, ông là Michael Faraday
# title: Chưa chính xác, ông đã tìm ra hợp chất benzene
# title: Thiên tài khoa học nào từng là cậu bé đóng sách?
# title: Chính xác, ông đã tìm ra hợp chất benzene
# Label 3 has 5 articles
# title: Đáp án câu 3
# title: Đáp án câu 2
# title: Đáp án câu 4
# title: Bốn câu đố đo tư duy logic của bạn
# title: Đáp án câu 1
# Label 2 has 5 articles
# title: Đáp án câu 3
# title: Rèn luyện trí não với bốn câu đố cuối tuần
# title: Đáp án câu 4
# title: Đáp án câu 1
# title: Đáp án câu 2
# Label 4 has 4 articles
# title: Phần 2
# title: Đáp án phần 2
# title: Đáp án phần 1
# title: Học tiếng Anh: Bài phát biểu của nữ sinh được đề cử Nobel Hòa Bình
# ###### END -> DOMAIN: Giáo dục, ALGORITHM: mean_shift <- ######
# ###### START -> DOMAIN: Giáo dục, ALGORITHM: dbscan <- ######
# Label 1 has 20 articles
# title: Học sinh đồng loạt nghỉ học sau án mạng trong trường
# title: Thầy giáo đại học trực tuyến ấn tượng cậu học trò 12 tuổi
# title: Đáp án câu 3
# title: Đáp án câu 2
# title: Đáp án câu 3
# title: Đáp án câu 1
# title: Thử tài giải năm câu đố tìm số
# title: Đáp án câu 5
# title: Đáp án câu 2
# title: Đáp án câu 4
# title: Cách vẽ bằng màu nước cho bức tranh đẹp mắt
# title: Cậu bé Mỹ giải cứu chị gái khỏi vụ bắt cóc
# title: Đáp án câu 4
# title: Lời khuyên dành cho những ông bố khi nuôi dạy con gái
# title: Năm câu đố tìm sự khác biệt
# title: Hơn 2.000 học sinh cả nước đạt giải quốc gia ViOlympic
# title: Thầy giáo bị khiển trách vì phạt 13 học sinh 'thụt dầu'
# title: 10 điều cần nhớ để dạy con thành người tử tế
# title: Bốn câu đố đo tư duy logic của bạn
# title: Đáp án câu 1
# Label 2 has 5 articles
# title: Chính xác, ông là Michael Faraday
# title: Chưa chính xác, ông là Michael Faraday
# title: Chưa chính xác, ông đã tìm ra hợp chất benzene
# title: Thiên tài khoa học nào từng là cậu bé đóng sách?
# title: Chính xác, ông đã tìm ra hợp chất benzene
# Label 3 has 5 articles
# title: Đáp án câu 3
# title: Rèn luyện trí não với bốn câu đố cuối tuần
# title: Đáp án câu 4
# title: Đáp án câu 1
# title: Đáp án câu 2
# Label 5 has 4 articles
# title: Phần 2
# title: Đáp án phần 2
# title: Đáp án phần 1
# title: Học tiếng Anh: Bài phát biểu của nữ sinh được đề cử Nobel Hòa Bình
# ###### END -> DOMAIN: Giáo dục, ALGORITHM: dbscan <- ######
# ###### START -> DOMAIN: Giáo dục, ALGORITHM: birch <- ######
# Label 14 has 5 articles
# title: Chính xác, ông là Michael Faraday
# title: Chưa chính xác, ông là Michael Faraday
# title: Chưa chính xác, ông đã tìm ra hợp chất benzene
# title: Thiên tài khoa học nào từng là cậu bé đóng sách?
# title: Chính xác, ông đã tìm ra hợp chất benzene
# Label 4 has 5 articles
# title: Đáp án câu 3
# title: Đáp án câu 2
# title: Đáp án câu 4
# title: Bốn câu đố đo tư duy logic của bạn
# title: Đáp án câu 1
# Label 5 has 5 articles
# title: Đáp án câu 3
# title: Rèn luyện trí não với bốn câu đố cuối tuần
# title: Đáp án câu 4
# title: Đáp án câu 1
# title: Đáp án câu 2
# Label 39 has 4 articles
# title: Phần 2
# title: Đáp án phần 2
# title: Đáp án phần 1
# title: Học tiếng Anh: Bài phát biểu của nữ sinh được đề cử Nobel Hòa Bình
# ###### END -> DOMAIN: Giáo dục, ALGORITHM: birch <- ######
# ###### START -> DOMAIN: Pháp luật, ALGORITHM: mean_shift <- ######
# Label 2 has 2 articles
# title: Nghi can sát hại 3 người thân ở Sài Gòn vì 'mẹ mắng'
# title: Gia đình ở Sài Gòn giấu hết dao trước khi 3 người bị sát hại
# Label 1 has 2 articles
# title: Tạm giữ 9 đối tượng trong vụ bắn người tại trường gà
# title: Truy bắt nhóm đối tượng bắn người tại trường gà
# Label 41 has 1 articles
# title: Cô gái nghi bị người yêu đâm chết vì đòi về quê
# Label 147 has 1 articles
# title: Vụ 5 học sinh và cô giáo bị đâm tại trường: Cô giáo kể lại giây phút kinh hoàng
# ###### END -> DOMAIN: Pháp luật, ALGORITHM: mean_shift <- ######
# ###### START -> DOMAIN: Pháp luật, ALGORITHM: dbscan <- ######
# Label 0 has 61 articles
# title: Vụ 5 học sinh và cô giáo bị đâm tại trường: Cô giáo kể lại giây phút kinh hoàng
# title: Vụ đánh bạc qua mạng 30.000 tỷ đồng: Xác định ông trùm người nước ngoài
# title: Hành trình truy tìm gã trai to khỏe chuyên lừa tình, cướp tiền các cô gái trẻ
# title: Xô xát tại quán ăn đêm, một nam thanh niên tử vong
# title: Giám đốc công ty tài chính cùng đàn em chém nhóm đối thủ trên phố
# title: Nhóm thanh thiếu niên miền Tây mang súng giả đi cướp sòng bạc
# title: Tài xế “rút ruột” hàng của công ty đem bán
# title: Tạm giữ 9 đối tượng trong vụ bắn người tại trường gà
# title: Đi đòi nợ, đâm người tử vong
# title: Mâu thuẫn tình cảm, vác mã tấu chém chết tình địch
# title: Vợ tử vong, chồng thoi thóp trong phòng trọ
# title: Hà Nội: Thanh niên 2 tiền án chuyên trộm đồ trong ô tô
# title: Nhóm “cẩu tặc” chạy tán loạn trong đêm khi bị vây bắt
# title: Loạn đả trong quán karaoke, khách bắn hai nhân viên phục vụ
# title: Lần đầu xử vụ thao túng giá chứng khoán, Tòa Hà Nội triệu tập hơn 1.000 bị hại
# title: Đường dây của trùm ma túy Văn Kính Dương hoạt động thế nào
# title: Nghi can xông vào trường đâm hàng loạt học sinh là người địa phương
# title: Đối tượng 5 tiền án vào tận buồng ngủ tháo trộm dây chuyền của trẻ nhỏ
# title: Vụ án mạng tại trường học ở Thanh Hóa: Hung thủ âm tính với ma túy
# title: "Đạo chích" lấy container từ Bình Dương đem về Đồng Nai trộm tài sản
# title: Vây bắt nhóm “quái xế” gây náo loạn trong đêm
# title: Một công an viên bị tố cưỡng bức tình dục 2 nữ tiếp viên
# title: Nghi vợ ngoại tình, người đàn ông giết tình địch rồi treo cổ tự vẫn
# title: Gã đàn ông ở Bình Phước chém chết người giữa đường vì ghen
# title: Về thăm vợ con vẫn tranh thủ qua đêm với tiếp viên quán hát
# title: Sau 2 năm, băng trộm 8,6 tỉ ở Thủ Đức bị bắt giữ
# title: Đối tượng đổ xăng phóng hỏa cửa hàng quần áo trẻ em bị bắt giữ
# title: 2 người đàn ông bất động trong phòng trọ, người đầy máu
# title: Cán bộ huyện đâm chết đồng nghiệp tại quán karaoke
# title: Án mạng trong phòng trọ ven Sài Gòn
# title: Cãi nhau với vợ lúc nhậu say, phóng hỏa đốt luôn nhà nhạc phụ
# title: Chàng rể đốt nhà bố vợ trong cơn giận
# title: Kẻ mang ba tiền án chuyên phá cửa nhà trọ
# title: 4 người trộm vịt thoát tội, gia chủ bị truy tố
# title: Nghi án chồng dùng dao bầu đoạt mạng vợ trong cơn cuồng ghen
# title: Cầm kiếm đi giải vây cho đàn em, nam thanh niên đâm chết người
# title: Bắt nhóm thanh niên làm giả giấy tờ rồi thuê xe ô tô mang đi cầm cố
# title: Nghi can phóng hỏa đốt xe ô tô 7 chỗ ra đầu thú
# title: Ăn trộm bất thành, đổ xăng đốt chủ nhà 76 tuổi đang ngủ
# title: Bị đánh toác đầu vì nói chủ quán nước 'chặt chém'
# title: Thanh niên sát hại con nợ tại quán ăn ở miền Tây
# title: Quán nước đánh khách ở Long An bị đập phá
# title: Truy bắt nhóm đối tượng bắn người tại trường gà
# title: Sinh viên trường cảnh sát truy đuổi bắt gọn hai tên cướp
# title: Khởi tố bị can sát hại 3 người trong căn nhà ven sông Đồng Nai
# title: Đoàn Thị Hương về tới Việt Nam sau khi được trả tự do tại Malaysia
# title: Hai nhóm thanh niên ở Hải Phòng ẩu đả vì nữ nhân viên quán bar
# title: Công an Hà Nội triệt phá đường dây làm bằng giả, thu 1 tấn phôi bằng
# title: Mâu thuẫn tình cảm, phóng hỏa thiêu rụi shop quần áo của vợ “hờ”?
# title: Hai nhóm thanh niên hỗn chiến vì tranh giành nữ tiếp viên quán bar
# title: Khởi tố vụ án dùng súng điện cướp tiệm vàng
# title: Đột kích quán bar tại Đà Nẵng: 80 người dương tính ma tuý
# title: Nam nghi can trộm xe SH có khuôn mặt nữ giới
# title: Nước mắt 3 người mẹ trong vụ án giết người hi hữu
# title: Hàng chục cảnh sát miền Tây vây ráp trường gà trong vườn vắng
# title: Bi kịch người mẹ đơn thân sát hại con trai
# title: Cô gái bị người yêu đâm chết ở phòng trọ khi đòi về quê
# title: Chồng chặn đường đâm gục vợ cũ giữa rừng cao su
# title: 100 cảnh sát đột kích quán bar tại Đà Nẵng
# title: Thanh niên bị bắn vì gian lận tại trường gà ở miền Tây
# title: Tổ CSGT bắt đối tượng táo tợn trộm xe máy giữa ban ngày
# Label 1 has 2 articles
# title: Nghi can sát hại 3 người thân ở Sài Gòn vì 'mẹ mắng'
# title: Gia đình ở Sài Gòn giấu hết dao trước khi 3 người bị sát hại
# Label 2 has 2 articles
# title: Vụ nổ súng trong quán karaoke: Nhóm dùng súng nhầm phòng!
# title: Nổ súng tại quán karaoke, 2 người trọng thương
# ###### END -> DOMAIN: Pháp luật, ALGORITHM: dbscan <- ######
# ###### START -> DOMAIN: Pháp luật, ALGORITHM: birch <- ######
# Label 21 has 1 articles
# title: Cô gái nghi bị người yêu đâm chết vì đòi về quê
# Label 163 has 1 articles
# title: Vụ 5 học sinh và cô giáo bị đâm tại trường: Cô giáo kể lại giây phút kinh hoàng
# Label 121 has 1 articles
# title: Vụ đánh bạc qua mạng 30.000 tỷ đồng: Xác định ông trùm người nước ngoài
# Label 122 has 1 articles
# title: Hành trình truy tìm gã trai to khỏe chuyên lừa tình, cướp tiền các cô gái trẻ
# ###### END -> DOMAIN: Pháp luật, ALGORITHM: birch <- ######
# ###### START -> DOMAIN: Khoa học, ALGORITHM: mean_shift <- ######
# Label 29 has 1 articles
# title: Lính cứu hỏa Thái Lan hướng dẫn bắt rắn hổ mang bằng tay không
# Label 28 has 1 articles
# title: Chiếc bẫy tử thần của kiến sư tử
# Label 11 has 1 articles
# title: Tại sao chim yến ngủ và giao phối khi bay?
# Label 50 has 1 articles
# title: Kỳ quan cổ đại nối 1.000 giếng dẫn nước dưới sa mạc Trung Quốc
# ###### END -> DOMAIN: Khoa học, ALGORITHM: mean_shift <- ######
# ###### START -> DOMAIN: Khoa học, ALGORITHM: dbscan <- ######
# Label 0 has 2 articles
# title: Việt Nam lần thứ 5 vô địch châu Á về xe tiết kiệm nhiên liệu
# title: Sinh viên Việt Nam sang Anh thi chế tạo xe tiết kiệm nhiên liệu
# ###### END -> DOMAIN: Khoa học, ALGORITHM: dbscan <- ######
# ###### START -> DOMAIN: Khoa học, ALGORITHM: birch <- ######
# Label 12 has 1 articles
# title: Lính cứu hỏa Thái Lan hướng dẫn bắt rắn hổ mang bằng tay không
# Label 13 has 1 articles
# title: Chiếc bẫy tử thần của kiến sư tử
# Label 14 has 1 articles
# title: Tại sao chim yến ngủ và giao phối khi bay?
# Label 0 has 1 articles
# title: Kỳ quan cổ đại nối 1.000 giếng dẫn nước dưới sa mạc Trung Quốc
# ###### END -> DOMAIN: Khoa học, ALGORITHM: birch <- ######
# ###### START -> DOMAIN: all, ALGORITHM: mean_shift <- ######
# Label 1 has 13 articles
# title: Filip Nguyễn hứa sẽ ghi điểm trong mắt HLV Park Hang Seo
# title: Alexander Đặng sẽ làm tất cả để được khoác áo đội tuyển Việt Nam
# title: HLV Park Hang Seo chốt ngày sang châu Âu “xem giò” cầu thủ Việt kiều
# title: HLV Park Hang-seo sẽ trực tiếp theo dõi bốn cầu thủ Việt kiều
# title: HLV Park Hang Seo tiết lộ danh sách cầu thủ Việt kiều trong tầm ngắm
# title: Người đại diện Alexander Đặng sẵn sàng làm tài xế cho HLV Park Hang Seo
# title: Các cựu binh đội tuyển Việt Nam ghi điểm trong mắt thầy Park
# title: Alexander Đặng mờ nhạt trong ngày HLV Park Hang Seo “xem giò”
# title: Cầu thủ Việt kiều Hà Lan được HLV Park Hang Seo quan tâm là ai?
# title: Bóng đá Việt Nam và giấc mơ World Cup
# title: HLV Park Hang Seo sang châu Âu "xem giò" cầu thủ Việt kiều
# title: HLV Park Hang Seo bất ngờ huỷ kế hoạch gặp Filip Nguyễn
# title: Alexander Đặng khó lọt vào mắt xanh của HLV Park Hang Seo
# Label 2 has 12 articles
# title: Mỹ để ngỏ khả năng can thiệp quân sự vào Venezuela sau đảo chính bất thành
# title: Xe bọc thép Trung Quốc sản xuất xuất hiện trong cuộc bạo động tại Venezuela
# title: Tổng thống Venezuela chúc mừng quân đội đánh bại âm mưu đảo chính của phe đối lập
# title: Cánh cửa hẹp cho phe đối lập sau đảo chính bất thành tại Venezuela
# title: “Dấu chân” của Mỹ trong kế hoạch đảo chính bất thành tại Venezuela
# title: Tổng thống Venezuela hô hào quân đội đánh bại 'kẻ chủ mưu đảo chính'
# title: Lộ kế hoạch 5.000 lính đánh thuê lật đổ ông Maduro
# title: Cảnh tượng hỗn loạn như chiến trường tại Venezuela sau âm mưu đảo chính
# title: Mỹ tìm cách rót tiền cho thủ lĩnh đối lập để lật đổ tổng thống Venezuela
# title: Phản ứng trái chiều của các nước về đảo chính Venezuela
# title: Hé lộ nguyên nhân khiến cuộc đảo chính tại Venezuela đổ vỡ vào phút chót
# title: Tổng thống Venezuela tuyên bố không bỏ trốn sang Cuba
# Label 3 has 6 articles
# title: Đáp án câu 3
# title: Đáp án câu 2
# title: Đáp án câu 1
# title: Đáp án câu 5
# title: Đáp án câu 4
# title: Năm câu đố tìm sự khác biệt
# Label 6 has 6 articles
# title: Trump tuyên bố tăng gấp đôi thuế với hàng Trung Quốc
# title: Chứng khoán Mỹ đi xuống vì Trump muốn tăng thuế với Trung Quốc
# title: Mỹ tăng sức ép để đạt thỏa thuận thương mại với Trung Quốc
# title: Trung Quốc có thể hoãn đàm phán thương mại với Mỹ
# title: Mất dần kiên nhẫn, ông Trump dọa tăng thuế với 200 tỷ USD hàng Trung Quốc
# title: Trung Quốc cân nhắc hủy đàm phán sau khi ông Trump đánh tiếng tăng thuế
# ###### END -> DOMAIN: all, ALGORITHM: mean_shift <- ######
# ###### START -> DOMAIN: all, ALGORITHM: dbscan <- ######
# Label 2 has 5 articles
# title: Đáp án câu 3
# title: Rèn luyện trí não với bốn câu đố cuối tuần
# title: Đáp án câu 4
# title: Đáp án câu 1
# title: Đáp án câu 2
# Label 4 has 4 articles
# title: Phần 2
# title: Đáp án phần 2
# title: Đáp án phần 1
# title: Học tiếng Anh: Bài phát biểu của nữ sinh được đề cử Nobel Hòa Bình
# Label 10 has 4 articles
# title: Giá vàng miếng bật tăng theo thế giới vì căng thẳng Mỹ - Trung
# title: Giá vàng bật tăng phiên cuối tuần
# title: Giá vàng miếng tăng theo thế giới
# title: Giá vàng miếng giảm cả trăm nghìn đồng mỗi lượng
# ###### END -> DOMAIN: all, ALGORITHM: dbscan <- ######
# ###### START -> DOMAIN: all, ALGORITHM: birch <- ######
# Label 1063 has 6 articles
# title: Đáp án câu 3
# title: Đáp án câu 2
# title: Đáp án câu 1
# title: Đáp án câu 5
# title: Đáp án câu 4
# title: Năm câu đố tìm sự khác biệt
# Label 1149 has 5 articles
# title: Chính xác, ông là Michael Faraday
# title: Chưa chính xác, ông là Michael Faraday
# title: Chưa chính xác, ông đã tìm ra hợp chất benzene
# title: Thiên tài khoa học nào từng là cậu bé đóng sách?
# title: Chính xác, ông đã tìm ra hợp chất benzene
# Label 1065 has 5 articles
# title: Đáp án câu 3
# title: Đáp án câu 2
# title: Đáp án câu 4
# title: Bốn câu đố đo tư duy logic của bạn
# title: Đáp án câu 1
# Label 1066 has 5 articles
# title: Đáp án câu 3
# title: Rèn luyện trí não với bốn câu đố cuối tuần
# title: Đáp án câu 4
# title: Đáp án câu 1
# title: Đáp án câu 2
# ###### END -> DOMAIN: all, ALGORITHM: birch <- ######
