# %% [markdown]
# # Phân cụm văn bản
# Bài toán giúp tự động phân cụm văn bản có cùng nội dùng vào với nhau
# <br>
# **Đầu vào:** Một tập các văn bản.
# <br>
# **Đầu ra:** Các văn bản được tự động gom vào với nhau.

# %%
import numpy as np
import pickle
import json
from sklearn.cluster import MeanShift, DBSCAN, Birch

# %%
from_date = '2019-05-01'
to_date = '2019-05-10'
domains = [
    'Thế giới',
    'Thể thao',
    'Kinh doanh',
    'Xã hội',
    'Chính trị',
    'Giáo dục',
    'Pháp luật',
    'Khoa học',
    'all'
]
# algs = ['mean_shift', 'dbscan', 'birch']
algs = ['mean_shift', 'dbscan']

# %%
def print_doc(doc, fields):
    source = doc['_source']

    for field in fields:
        if field in source:
            print ('{}: {}'.format(field, source[field]))
    
def report_model(model_file, docs_file):
    model = pickle.load(open(model_file, 'rb'))
    with open(docs_file, 'r', encoding='utf-8') as f:
        docs = json.load(f)
    
    label_count = {}
    labels = model.labels_.tolist()
    
    for idx, label in enumerate(labels):
        if not label in label_count:
            label_count[label] = [idx]
        else:
            label_count[label].append(idx)
    
    # sort label count
    count_pair = []
    for label, idxes in label_count.items():
        count_pair.append((label, len(idxes)))

    count_pair.sort(key=lambda p: -p[1])
    
    print ('Total labels: {}, Total docs: {}'.format(len(count_pair), len(docs)))
    for label, count in count_pair[0:5]:
        if not label == -1:
            print ('Label {} has {} articles'.format(label, count))
            for idx in label_count[label]:
                print_doc(docs[idx], ['title'])
            print ('\n')

# %%
PREFIX = '/media/sinhblack/Media1/works/article_research/'
for domain in domains:
    for alg in algs:
        model_file = '{}data/models/{}_{}_{}_{}.pkl'.format(PREFIX, domain, from_date, to_date, alg)
        docs_file = '{}data/by_domain/{}_{}_{}.json'.format(PREFIX, domain.replace(' ', '_'), from_date, to_date)
        
        print ('###### START -> DOMAIN: {}, ALGORITHM: {} <- ######'.format(domain, alg))
        report_model(model_file, docs_file)
        print ('###### END -> DOMAIN: {}, ALGORITHM: {} <- ######'.format(domain, alg))
        print ('\n\n\n')
# Out:
# ###### START -> DOMAIN: Thế giới, ALGORITHM: mean_shift <- ######
# Total labels: 326, Total docs: 327
# Label 0 has 2 articles
# title: Tàu sân bay đầu tiên của Thổ Nhĩ Kỳ bốc cháy tại cảng
# title: Tàu sân bay đầu tiên của Thổ Nhĩ Kỳ bốc cháy tại cảng
#
#
# Label 321 has 1 articles
# title: Triều Tiên phóng thử hàng loạt tên lửa tầm ngắn
#
#
# Label 310 has 1 articles
# title: Đoàn Thị Hương được trả tự do
#
#
# Label 205 has 1 articles
# title: Mỹ để ngỏ khả năng can thiệp quân sự vào Venezuela sau đảo chính bất thành
#
#
# Label 271 has 1 articles
# title: Mẫu pháo phòng không thảm họa từng chĩa nòng vào nhiều tướng Mỹ
#
#
# ###### END -> DOMAIN: Thế giới, ALGORITHM: mean_shift <- ######
#
#
#
#
# ###### START -> DOMAIN: Thế giới, ALGORITHM: dbscan <- ######
# Total labels: 18, Total docs: 327
# Label 0 has 26 articles
# title: Mỹ để ngỏ khả năng can thiệp quân sự vào Venezuela sau đảo chính bất thành
# title: Thủ lĩnh đối lập Venezuela lý giải việc đảo chính thất bại
# title: Ông Trump úp mở về kế hoạch lớn ở Venezuela vào tuần tới
# title: Nga cảnh báo hậu quả nếu Mỹ không từ bỏ ý định lật đổ Tổng thống Venezuela
# title: Nga - Mỹ quyết "so găng" ở Venezuela
# title: Đánh chìm tàu sân bay Mỹ: Nói dễ hơn làm
# title: Câu hỏi bỏ ngỏ sau đảo chính thất bại ở Venezuela
# title: Venezuela ra trát bắt giữ thủ lĩnh tinh thần của phe đối lập sau đảo chính bất thành
# title: Khoảnh khắc máy bay Nga chở 78 người lao xuống đường băng, bốc cháy
# title: Bên trong máy bay Nga cháy ngùn ngụt khi hạ cánh
# title: Tổng thống Venezuela kêu gọi đối thoại để "sửa chữa sai lầm"
# title: Ông Trump phàn nàn bị "lấy mất" 2 năm nhiệm kỳ
# title: Mỹ đưa tàu sân bay, máy bay ném bom đến Trung Đông
# title: Nhân chứng vụ rơi máy bay Nga: Máy bay cháy rực như ngọn đuốc
# title: Giới an ninh, quân sự Mỹ họp khẩn về phương án ở Venezuela
# title: Đảo chính Venezuela: “Vết rạn” mới trong quan hệ Nga-Mỹ
# title: Cánh cửa hẹp cho phe đối lập sau đảo chính bất thành tại Venezuela
# title: Nga cảnh báo hậu quả nặng nề nếu Mỹ tiếp tục can thiệp vào Venezuela
# title: Nga lên kế hoạch ngăn Mỹ can thiệp quân sự vào Venezuela
# title: Phản ứng trái chiều của các nước về đảo chính Venezuela
# title: Ngoại trưởng Pompeo: "Mọi hành động của Mỹ ở Venezuela đều hợp pháp"
# title: “Dấu chân” của Mỹ trong kế hoạch đảo chính bất thành tại Venezuela
# title: Rơi trực thăng quân sự Venezuela, 7 người thiệt mạng
# title: Lộ kế hoạch 5.000 lính đánh thuê lật đổ ông Maduro
# title: Cựu binh Pháp chia sẻ về ký ức Điện Biên Phủ
# title: Maduro tổ chức 'ngày đối thoại' để sửa chữa sai lầm
#
#
# Label 1 has 16 articles
# title: Những con số choáng ngợp về lễ đăng cơ của Quốc vương Thái Lan
# title: Sứ mệnh lớn lao của tân Quốc vương Thái Lan
# title: Vai trò biểu tượng quốc gia của Vua Thái Lan
# title: 300 UAV trình diễn ánh sáng mừng Quốc vương Thái Lan đăng quang
# title: Quốc vương Thái Lan ngồi kiệu dát vàng 16 người khiêng trong lễ rước đăng quang
# title: Voi quý được coi là biểu tượng cho quyền uy của quốc vương Thái Lan
# title: Quốc vương Thái Lan ban danh hiệu mới cho thành viên hoàng gia
# title: Quốc vương Thái Lan tuyên bố trị vì bằng chính nghĩa ngay sau đăng quang
# title: Quốc vương Thái Lan bái Phật trước khi đăng quang
# title: Quốc vương Thái Lan kết hôn với nữ tướng ngay trước lễ đăng cơ
# title: Thái Lan rước bảo vật hoàng gia trước lễ đăng quang của tân vương
# title: 5 báu vật hoàng gia được trao trong lễ đăng cơ của Quốc vương Thái Lan
# title: Quốc vương Thái Lan kết hôn với nữ tướng
# title: Quốc vương Thái Lan kêu gọi người dân đoàn kết sau khi đăng quang
# title: Các nghi thức trong lễ đăng quang của tân vương Thái Lan
# title: Quốc vương Thái Lan đội vương miện hơn 7kg, chính thức đăng quang
#
#
# Label 2 has 4 articles
# title: Cuộc sống khác cổ tích của tân Hoàng hậu Nhật Bản
# title: Đường tới ngai vàng của tân Nhật hoàng Naruhito
# title: Tân Nhật hoàng Naruhito lên ngôi
# title: Lễ đăng cơ trang trọng của tân Nhật hoàng Naruhito
#
#
# Label 7 has 4 articles
# title: Tên lửa Triều Tiên không vươn tới vùng đặc quyền kinh tế Nhật Bản
# title: Bức ảnh "triệu tấm có một" trong vụ thử tên lửa Triều Tiên
# title: Chuyên gia “giải mã” vụ phóng tên lửa mới của Triều Tiên
# title: Triều Tiên bất ngờ phóng tên lửa tầm ngắn
#
#
# ###### END -> DOMAIN: Thế giới, ALGORITHM: dbscan <- ######
#
#
#
#
# ###### START -> DOMAIN: Thể thao, ALGORITHM: mean_shift <- ######
# Total labels: 261, Total docs: 261
# Label 157 has 1 articles
# title: Barcelona nhận tin dữ trước thềm trận chiến gặp Liverpool
#
#
# Label 248 has 1 articles
# title: Những khoảnh khắc tệ hại của Man Utd trước Huddersfield
#
#
# Label 238 has 1 articles
# title: Gary Neville: “MU là tập thể của những con người hèn kém”
#
#
# Label 107 has 1 articles
# title: Arsenal thắng cách biệt hai bàn ở lượt đi bán kết Europa League
#
#
# Label 106 has 1 articles
# title: Solskjaer trách móc hàng tiền đạo của Man Utd
#
#
# ###### END -> DOMAIN: Thể thao, ALGORITHM: mean_shift <- ######
#
#
#
#
# ###### START -> DOMAIN: Thể thao, ALGORITHM: dbscan <- ######
# Total labels: 7, Total docs: 261
# Label 0 has 170 articles
# title: Barcelona nhận tin dữ trước thềm trận chiến gặp Liverpool
# title: Những khoảnh khắc tệ hại của Man Utd trước Huddersfield
# title: Gary Neville: “MU là tập thể của những con người hèn kém”
# title: Arsenal thắng cách biệt hai bàn ở lượt đi bán kết Europa League
# title: Solskjaer trách móc hàng tiền đạo của Man Utd
# title: Solskjaer: 'Không bất ngờ khi Man Utd rớt khỏi top 4'
# title: Gary Neville: 'Tôi thích xem Huddersfield đá hơn Man Utd'
# title: Ajax đoạt danh hiệu đầu tiên, hướng đến cú ăn ba
# title: Chiellini: 'Messi và Ronado như Federer - Nadal của quần vợt'
# title: Klopp: 'Trái tim giúp Liverpool chiến thắng'
# title: Tháng Ramadan đe dọa cơ hội 'ăn ba' của Ajax
# title: Ronaldo: 'Nhiều người chờ đợi tôi đá hỏng phạt đền hoặc gục ngã'
# title: Federer chung nhánh Djokovic ở Madrid Mở rộng 2019
# title: Liverpool thảm bại trước Barcelona, HLV Jurgen Klopp quyết vô địch Premier League
# title: Vắng Messi và Suarez, Barcelona gục ngã trước Celta Vigo
# title: Barcelona - Liverpool: Cuộc chiến khó lường
# title: HLV Barcelona choáng vì siêu phẩm của Messi
# title: Ramsey gửi tâm thư “đầy nước mắt” chia tay người hâm mộ Arsenal
# title: Emery vô tình làm lộ chiến thuật của Arsenal tại Europa League
# title: HAGL - Nam Định: HLV Lee Tae-hoon tìm thắng lợi đầu tay
# title: Ngoại binh khen Quang Hải chơi đồng đội
# title: HLV Klopp chưa từng thắng ở Tây Ban Nha
# title: Quang Hải giúp Hà Nội thắng đậm tại AFC Cup
# title: Bác sỹ tim mạch lo Casillas phải giải nghệ
# title: Ramsey rơi nước mắt trong ngày chia tay Arsenal
# title: Man City - Leicester: Chạm tay vào ngôi báu
# title: Kompany bực vì đồng đội khuyên đừng sút trong pha ghi bàn
# title: McManaman: 'Alisson Becker đã không tuân lệnh Klopp'
# title: Cầu thủ B.Bình Dương chấn thương nặng được trọng tài cấp cứu ngay trên sân
# title: Ten Hag: 'Ajax đã chiến đấu như những chú sư tử'
# title: Hàng loạt ngôi sao Man Utd bị giảm lương vì không vào top 4
# title: Real thắng trận sân nhà thứ năm liên tiếp ở La Liga
# title: MU thét giá trên trời cho Paul Pogba
# title: HLV Mourinho: “Messi là vị Chúa của bóng đá”
# title: Jurgen Klopp: “Liverpool sẽ dập tắt giấc mơ của Messi”
# title: Barcelona sẽ thăng hoa nhờ lối chơi thực dụng?
# title: Tottenham 0-1 Ajax: Pha làm bàn của Van de Beek
# title: HLV Mourinho bất ngờ lên tiếng trách móc MU
# title: Messi lập cú đúp giúp Barca thắng Liverpool 3-0
# title: Thủ quân Liverpool chờ phép màu cản bước Man City
# title: Cựu tiền đạo Liverpool: 'Suarez hành động như một con chuột'
# title: Barcelona 3-0 Liverpool: Cú đúp của Messi
# title: Barca thất bại lần đầu sau nửa năm ở La Liga
# title: HLV Jurgen Klopp cảm thấy “tâm phục, khẩu phục” trước Messi
# title: Nou Camp lập kỷ lục về khán giả ở trận Barca - Liverpool
# title: HLV Valverde nhắc lại trận thua Roma để cảnh tỉnh Barca
# title: Van Dijk bị nghi cầu cứu đồng đội khi đối đầu Messi
# title: Alexander-Arnold: 'Mọi chuyện đều có thể xảy ra tại Anfield'
# title: Chủ tịch Napoli: 'Nên đập bỏ Champions League và Europa League'
# title: Nhìn lại trận hòa cay đắng của Arsenal trước Brighton
# title: Cận cảnh cuộc sống hạnh phúc với vợ đẹp, con thơ của C.Ronaldo
# title: Man Utd hết cửa vào top 4 Ngoại hạng Anh
# title: McIlroy giữ đỉnh bảng vòng một Wells Fargo
# title: Chelsea - Watford: Thời cơ cho Chelsea vào top 3
# title: Bournemouth 1-0 Tottenham: Son Heung Min bị đuổi, bàn thua phút bù giờ
# title: Messi thừa nhận 'ăn may' với cú sút phạt vào lưới Liverpool
# title: Aubameyang quyết tâm giành danh hiệu Vua phá lưới Premier League
# title: Messi nói gì sau khi chạm mốc 600 bàn thắng cho Barcelona?
# title: HLV Tottenham nói gì sau thất bại cay đắng trước Ajax?
# title: Giá trị của Quế Ngọc Hải trong ngày trở lại
# title: Sự khác biệt giữa “hai người cũ” của Liverpool trong màu áo Barcelona
# title: Ajax phớt lờ Tottenham, tập trung giành Cup Hà Lan
# title: Barca chưa từng bị loại khi thắng 3-0 ở lượt đi các Cup châu Âu
# title: Rakitic: 'Messi nói gì chúng tôi cũng nghe'
# title: Casillas bị trụy tim trên sân tập
# title: Guardiola: 'Liverpool không sụp đổ vì thua Barca'
# title: Klopp văng tục khi nhắc đến bàn thắng của học trò
# title: Nadal bỏ tập trước thềm Madrid Mở rộng vì dính virus
# title: Cựu Chủ tịch khuyên Man Utd bỏ thêm một mùa giải
# title: Chelsea 3-0 Watford: The Blues vào top 3
# title: Sarri nhận sai khi để Kante thi đấu
# title: Liverpool hạ Newcastle để lên đỉnh bảng
# title: HLV Park sang Na Uy, theo dõi tiền đạo Việt kiều
# title: Mourinho đá xoáy Neville và Scholes
# title: HLV Juventus: 'Ajax quá may ở Champions League'
# title: Newcastle 2-3 Liverpool: Chiến thắng khó khăn
# title: HLV Ajax: “Chúng tôi đã chiến đấu như sư tử”
# title: B.Bình Dương phải thắng để duy trì hy vọng vào vòng knock-out AFC Cup
# title: Arsenal - Valencia: “Pháo thủ” có qua được khủng hoảng?
# title: Salah có nguy cơ lỡ trận bán kết lượt về gặp Barca
# title: Pochettino thừa nhận sai lầm dẫn tới trận thua Ajax
# title: 76ers nắm lợi thế tại bán kết play-off miền Đông NBA
# title: Thủ quân Ajax tiếc vì không thể thắng Tottenham đậm hơn
# title: Klopp xem thường sức nóng của Nou Camp
# title: Chờ "derby London" ở chung kết Europa League
# title: Salah phải nghỉ trận bán kết lượt về với Barca
# title: Huddersfield 1-1 Man Utd: “Quỷ đỏ” hết cơ hội vào top 4
# title: Thái Lan tìm HLV mới sau King's Cup
# title: Emery: 'Arsenal cần quên Ngoại hạng Anh, tập trung cho Europa League'
# title: Viettel chia điểm với SLNA
# title: Hai hậu vệ Liverpool lập kỷ lục kiến tạo
# title: Các ông chủ Qatar tính phương án bán PSG
# title: Anh Đức ghi bàn, B.Bình Dương nuôi hy vọng đi tiếp tại AFC Cup
# title: Alba: 'Barca sẽ rất nhớ Messi một khi anh ấy giải nghệ'
# title: Barca - Liverpool: Chờ bữa tiệc bóng đá tấn công
# title: Bình Dương đè bẹp Persija Jakarta ở AFC Cup
# title: Man City đảm bảo tương lai cho Mendy
# title: Ngoại hạng Anh xác định xong ba đội xuống hạng
# title: Casillas xuất viện sau ca cấp cứu vì bị trụy tim
# title: Võ sĩ Việt huỷ thi đấu với cao thủ Vịnh Xuân Flores
# title: Arsenal 1-1 Brighton: Trận hòa cay đắng với "Pháo thủ"
# title: Những khoảnh khắc Messi nhấn chìm Liverpool tại Nou Camp
# title: Max Homa vô địch giải Wells Fargo
# title: Canelo thống nhất đai vô địch hạng trung nhờ tính điểm
# title: Mourinho: 'Messi là Chúa tể bóng đá'
# title: Barca từng hai lần vô địch sau khi Messi lập cú đúp ở bán kết
# title: Thắng đậm đại diện Campuchia, Hà Nội FC sáng cửa đi tiếp ở AFC Cup
# title: Liverpool đối đầu với Barcelona: Trông vào “bức tường thành”
# title: Vertonghen đổ máu trong ngày Tottenham bại trận trước Ajax
# title: Messi ăn vạ trước khi lập siêu phẩm vào lưới Liverpool?
# title: Ba nguyên nhân khiến Liverpool thua cay đắng trên sân Barcelona
# title: Báo chí thế giới ngả mũ trước “thiên tài” Lionel Messi
# title: Guardiola: 'Liverpool là đối thủ khó chơi nhất sự nghiệp'
# title: Allegri: 'Ronaldo sẽ bùng nổ sau khi Messi ghi bàn thứ 600'
# title: Eriksen: 'Tottenham giúp Ajax chơi hay hơn'
# title: Klopp: 'Nếu muốn chiến thắng, bạn phải chấp nhận mình có thể thua'
# title: Arsenal xác nhận chia tay “chân gỗ” Welbeck
# title: Guardiola bất ngờ khi Man City có gần 100 điểm mùa này
# title: Guardiola: 'Liverpool không chịu áp lực vì chức vô địch nằm trong tay Man City'
# title: Flores bức xúc vì bị võ sĩ Việt huỷ đấu
# title: Chủ tịch Barca: 'Sẽ có 10 bức tượng Messi ở sân Nou Camp'
# title: Nadal: ‘Sự tự tin của tôi đã trở lại’
# title: Cầu thủ Bình Dương bị chấn động não, lún thái dương
# title: Chelsea giành lợi thế sau lượt đi bán kết Europa League
# title: Semenya: 'Không ai có thể bắt tôi ngừng chạy'
# title: CĐV Việt Nam vẫn mong chờ chung kết toàn Anh ở Champions League
# title: HLV Lee Tae-hoon giành chiến thắng đầu tiên cùng HAGL
# title: Van Dijk: 'Thật dễ chịu khi không phải gặp Messi mỗi mùa'
# title: C.Ronaldo lại sắm vai người hùng giúp Juventus thoát thua
# title: Newcastle - Liverpool: Nỗi niềm khó nói của Rafa Benitez
# title: Liverpool đón trụ cột trở lại ở đại chiến với Barcelona
# title: Đội tuyển Việt Nam khủng hoảng trung phong: Thầy Park nhắm đến Alexander Đặng?
# title: Chấm điểm trận Barcelona đại thắng Liverpool: Messi đạt điểm 10
# title: Arsenal 3-1 Valencia: Cú đúp của Lacazette
# title: Hòa trên sân Frankfurt, Chelsea giành lợi thế ở bán kết Europa League
# title: Rio Ferdinand, Luis Figo đến Việt Nam trong tháng Sáu
# title: Tiger Woods vẫn chưa trở lại thi đấu sau Masters
# title: Barca bắt kịp cột mốc ghi bàn của Real tại Champions League
# title: Klopp: 'Liverpool đã chơi trận sân khách hay nhất ở Champions League'
# title: Ajax “bơi trong tiền” nếu như lọt vào chung kết Champions League
# title: Chelsea lấy vị trí thứ ba của Tottenham
# title: Arsenal cạn hy vọng top 4 Ngoại hạng Anh
# title: Báo Anh ám chỉ Messi gian lận khi phá lưới Liverpool
# title: Dominic Thiem: 'Roland Garros là mục tiêu của đời tôi'
# title: Messi chạm mốc 600 bàn cho Barca
# title: Iker Casillas nhập viện khẩn cấp do đau tim
# title: Chelsea và liều thuốc thử hạng nặng ở bán kết Europa League
# title: Newcastle - Liverpool: Gượng dậy sau thảm bại
# title: Wenger: 'Messi là nguyên nhân khiến Liverpool sụp đổ trước Barca'
# title: Messi chỉ trích CĐV nhà khi la ó Coutinho
# title: 'Suarez tái ngộ để cắn Liverpool'
# title: Truyền thông Anh ngả mũ trước Messi
# title: Tottenham bại trận sau khi bị đuổi hai người
# title: Xavi giải nghệ, chuẩn bị làm HLV
# title: Chelsea chắc chỗ trong top 4 Ngoại hạng Anh
# title: Ronaldo lại vượt Messi sau khi chạm mốc 600 bàn
# title: Hàng nghìn CĐV kiến nghị UEFA phạt nguội Messi
# title: Bayern nới khoảng cách với Dortmund lên 5 điểm
# title: Wimbledon công bố mức tiền thưởng kỷ lục
# title: Những điểm nhấn trước cuộc đối đầu kinh điển Barcelona - Liverpool
# title: Danh thủ Xavi giã từ sự nghiệp ở tuổi 39
# title: C.Ronaldo, Messi cán mốc 600 bàn thắng diễn ra như thế nào?
# title: Van Dijk thừa nhận nỗi ám ảnh về Messi
# title: Lionel Messi: Người khổng lồ trong khuôn hình tí hon
# title: Man Utd sẵn sàng mất tiền để tống khứ Sanchez
# title: Barca cho hàng loạt trụ cột dưỡng sức, chờ tái đấu Liverpool
# title: Chelsea khủng hoảng hàng thủ ở bán kết lượt đi Europa League
# title: Pochettino lấy Messi làm gương cho học trò
# title: Man City đòi lại ngôi đầu sau trận thắng tối thiểu Leicester
# title: Klopp: 'Liverpool sẽ thử ghi bốn bàn vào lưới Barca'
#
#
# Label 2 has 8 articles
# title: HLV Park Hang Seo chốt ngày sang châu Âu “xem giò” cầu thủ Việt kiều
# title: Alexander Đặng mờ nhạt trong ngày HLV Park Hang Seo “xem giò”
# title: HLV Park Hang Seo tiết lộ danh sách cầu thủ Việt kiều trong tầm ngắm
# title: Người đại diện Alexander Đặng sẵn sàng làm tài xế cho HLV Park Hang Seo
# title: Filip Nguyễn hứa sẽ ghi điểm trong mắt HLV Park Hang Seo
# title: HLV Park Hang Seo sang châu Âu "xem giò" cầu thủ Việt kiều
# title: HLV Park Hang Seo bất ngờ huỷ kế hoạch gặp Filip Nguyễn
# title: Alexander Đặng khó lọt vào mắt xanh của HLV Park Hang Seo
#
#
# Label 1 has 3 articles
# title: Vòng 8 V-League 2019: B.Bình Dương có cản nổi đội đầu bảng Hà Nội?
# title: HLV Hà Nội chê Bình Dương chơi tiêu cực
# title: Tấn Trường mắc lỗi, khiến Bình Dương hoà Hà Nội
#
#
# Label 5 has 3 articles
# title: Các cựu binh đội tuyển Việt Nam ghi điểm trong mắt thầy Park
# title: Bóng đá Việt Nam hướng mục tiêu kép World Cup và SEA Games
# title: Bóng đá Việt Nam và giấc mơ World Cup
#
#
# ###### END -> DOMAIN: Thể thao, ALGORITHM: dbscan <- ######
#
#
#
#
# ###### START -> DOMAIN: Kinh doanh, ALGORITHM: mean_shift <- ######
# Total labels: 222, Total docs: 225
# Label 1 has 2 articles
# title: Giá vàng miếng bật tăng theo thế giới vì căng thẳng Mỹ - Trung
# title: Giá vàng miếng tăng theo thế giới
#
#
# Label 0 has 2 articles
# title: Richard Mille lần đầu ra mắt dây đồng hồ carbon TPT siêu nhẹ
# title: Richard Mille lần đầu ra mắt dây đồng hồ Carbon TPT siêu nhẹ
#
#
# Label 2 has 2 articles
# title: TEKCOM ra mắt sản phẩm ECO FORM cho thị trường cốp-pha phổ thông Việt Nam
# title: TEKCOM ra mắt sản phẩm ECO FORM cho thị trường cốp-pha phổ thông tại Việt Nam
#
#
# Label 14 has 1 articles
# title: “Ông chủ” doanh nghiệp thủy sản trúng số độc đắc gần 120 tỷ đồng
#
#
# Label 123 has 1 articles
# title: Tuyệt phẩm cây cảnh cứ đụng vào là tỏa hương, giá bán tới 2 tỷ đồng
#
#
# ###### END -> DOMAIN: Kinh doanh, ALGORITHM: mean_shift <- ######
#
#
#
#
# ###### START -> DOMAIN: Kinh doanh, ALGORITHM: dbscan <- ######
# Total labels: 13, Total docs: 225
# Label 3 has 6 articles
# title: Thủ tướng chỉ đạo làm rõ việc tăng giá điện
# title: Bộ Công Thương sẽ kiểm tra tác động tăng giá điện
# title: Bộ Công Thương lập 3 đoàn kiểm tra liên quan đến việc tăng giá điện
# title: Phó thủ tướng yêu cầu tiếp tục theo dõi tác động tăng giá điện
# title: Thủ tướng yêu cầu kiểm tra lại việc đúng sai trong tăng giá điện
# title: Phó thủ tướng yêu cầu đánh giá tác động của việc tăng giá điện
#
#
# Label 7 has 4 articles
# title: Giá vàng miếng bật tăng theo thế giới vì căng thẳng Mỹ - Trung
# title: Giá vàng bật tăng phiên cuối tuần
# title: Giá vàng miếng tăng theo thế giới
# title: Giá vàng miếng giảm cả trăm nghìn đồng mỗi lượng
#
#
# Label 2 has 3 articles
# title: Giá USD bật tăng mạnh
# title: Tỷ giá USD/VND tiếp tục sụt giảm
# title: Mua thêm 8,35 tỷ USD, tỷ giá trung tâm đạt mức cao kỷ lục
#
#
# Label 4 has 3 articles
# title: Doanh nghiệp Việt rộng cửa nhờ CPTPP
# title: Bình quân mỗi tháng Honda Việt Nam thu hơn 7.600 tỷ
# title: Đại gia ngoại dòm ngó "cỗ máy in tiền" số 1 Việt Nam
#
#
# ###### END -> DOMAIN: Kinh doanh, ALGORITHM: dbscan <- ######
#
#
#
#
# ###### START -> DOMAIN: Xã hội, ALGORITHM: mean_shift <- ######
# Total labels: 122, Total docs: 122
# Label 101 has 1 articles
# title: Công bố thanh tra toàn diện Khu Liên hợp thể thao quốc gia Mỹ Đình
#
#
# Label 98 has 1 articles
# title: Hai du khách tố bị đánh vỡ đầu vì phản ứng chuyện "chặt chém"
#
#
# Label 81 has 1 articles
# title: Nghi án nghịch tử dùng búa hành hung cha, bị cha đánh vỡ đầu
#
#
# Label 54 has 1 articles
# title: Văn hóa rượu bia quá dễ dãi gây nên vấn nạn tài xế “ma men”!
#
#
# Label 66 has 1 articles
# title: Hà Nội: Nghi vấn xe biển xanh tông tài xế xe ôm bị thương rồi bỏ chạy
#
#
# ###### END -> DOMAIN: Xã hội, ALGORITHM: mean_shift <- ######
#
#
#
#
# ###### START -> DOMAIN: Xã hội, ALGORITHM: dbscan <- ######
# Total labels: 3, Total docs: 122
# Label 1 has 6 articles
# title: Người dân "tay xách nách mang" trở lại Thủ đô sau nghỉ lễ
# title: Đại tướng Lê Đức Anh và những phút sinh tử trên trận mạc
# title: Chiến sỹ Điện Biên kể chuyện
# title: Tăng giá điện 2019: Hãy là người tiêu dùng thông minh
# title: Cảng cá vừa nạo vét đã bị bồi lấp trở lại, ngư dân khóc ròng
# title: Hà Nội: Bắt xe khách 29 chỗ nhồi… 73 người
#
#
# Label 0 has 2 articles
# title: Linh xa chở linh cữu Đại tướng Lê Đức Anh qua các tuyến phố Hà Nội
# title: Kính cẩn, xúc động đón linh cữu Đại tướng Lê Đức Anh về đến Sài Gòn
#
#
# ###### END -> DOMAIN: Xã hội, ALGORITHM: dbscan <- ######
#
#
#
#
# ###### START -> DOMAIN: Chính trị, ALGORITHM: mean_shift <- ######
# Total labels: 30, Total docs: 30
# Label 27 has 1 articles
# title: Kết luận về sai phạm của 1 nguyên Phó Thủ tướng, 1 Bộ trưởng, 5 Thứ trưởng
#
#
# Label 13 has 1 articles
# title: Lời cảm ơn của Ban Lễ tang và gia đình nguyên Chủ tịch nước, Đại tướng Lê Đức Anh
#
#
# Label 26 has 1 articles
# title: Quên ngày nghỉ, cán bộ, chính quyền giúp dân khắc phục hậu quả lốc xoáy
#
#
# Label 24 has 1 articles
# title: Bạc Liêu đề nghị đưa game bắn cá vào danh mục kinh doanh có điều kiện
#
#
# Label 6 has 1 articles
# title: Máy bay đưa nguyên Chủ tịch nước Lê Đức Anh về nơi an nghỉ cuối cùng tại TPHCM
#
#
# ###### END -> DOMAIN: Chính trị, ALGORITHM: mean_shift <- ######
#
#
#
#
# ###### START -> DOMAIN: Chính trị, ALGORITHM: dbscan <- ######
# Total labels: 2, Total docs: 30
# Label 0 has 2 articles
# title: Máy bay đưa nguyên Chủ tịch nước Lê Đức Anh về nơi an nghỉ cuối cùng tại TPHCM
# title: Lễ an táng Đại tướng, nguyên Chủ tịch nước Lê Đức Anh
#
#
# ###### END -> DOMAIN: Chính trị, ALGORITHM: dbscan <- ######
#
#
#
#
# ###### START -> DOMAIN: Giáo dục, ALGORITHM: mean_shift <- ######
# Total labels: 60, Total docs: 76
# Label 0 has 10 articles
# title: Đáp án câu 3
# title: Đáp án câu 2
# title: Đáp án câu 3
# title: Đáp án câu 1
# title: Đáp án câu 5
# title: Đáp án câu 2
# title: Đáp án câu 4
# title: Đáp án câu 4
# title: Năm câu đố tìm sự khác biệt
# title: Đáp án câu 1
#
#
# Label 1 has 4 articles
# title: Đáp án câu 3
# title: Đáp án câu 4
# title: Đáp án câu 1
# title: Đáp án câu 2
#
#
# Label 2 has 3 articles
# title: Phần 2
# title: Đáp án phần 2
# title: Đáp án phần 1
#
#
# Label 4 has 2 articles
# title: Chính xác, ông là Michael Faraday
# title: Chưa chính xác, ông là Michael Faraday
#
#
# Label 3 has 2 articles
# title: Chưa chính xác, ông đã tìm ra hợp chất benzene
# title: Chính xác, ông đã tìm ra hợp chất benzene
#
#
# ###### END -> DOMAIN: Giáo dục, ALGORITHM: mean_shift <- ######
#
#
#
#
# ###### START -> DOMAIN: Giáo dục, ALGORITHM: dbscan <- ######
# Total labels: 2, Total docs: 76
# Label 0 has 26 articles
# title: Chính xác, ông là Michael Faraday
# title: Đáp án câu 3
# title: Đáp án câu 2
# title: Đáp án câu 3
# title: Đáp án câu 3
# title: Đáp án câu 1
# title: Thử tài giải năm câu đố tìm số
# title: Rèn luyện trí não với bốn câu đố cuối tuần
# title: Đáp án câu 4
# title: Đáp án câu 1
# title: Phần 2
# title: Chưa chính xác, ông là Michael Faraday
# title: Đáp án câu 5
# title: Chưa chính xác, ông đã tìm ra hợp chất benzene
# title: Đáp án câu 2
# title: Đáp án câu 4
# title: Đáp án câu 4
# title: Đáp án phần 2
# title: Thiên tài khoa học nào từng là cậu bé đóng sách?
# title: Năm câu đố tìm sự khác biệt
# title: Đáp án phần 1
# title: Học tiếng Anh: Bài phát biểu của nữ sinh được đề cử Nobel Hòa Bình
# title: Đáp án câu 2
# title: Bốn câu đố đo tư duy logic của bạn
# title: Chính xác, ông đã tìm ra hợp chất benzene
# title: Đáp án câu 1
#
#
# ###### END -> DOMAIN: Giáo dục, ALGORITHM: dbscan <- ######
#
#
#
#
# ###### START -> DOMAIN: Pháp luật, ALGORITHM: mean_shift <- ######
# Total labels: 184, Total docs: 184
# Label 54 has 1 articles
# title: Cô gái nghi bị người yêu đâm chết vì đòi về quê
#
#
# Label 146 has 1 articles
# title: Vụ 5 học sinh và cô giáo bị đâm tại trường: Cô giáo kể lại giây phút kinh hoàng
#
#
# Label 2 has 1 articles
# title: Vụ đánh bạc qua mạng 30.000 tỷ đồng: Xác định ông trùm người nước ngoài
#
#
# Label 161 has 1 articles
# title: Hành trình truy tìm gã trai to khỏe chuyên lừa tình, cướp tiền các cô gái trẻ
#
#
# Label 27 has 1 articles
# title: Đề nghị truy tố nguyên Tổng giám đốc Bảo hiểm xã hội
#
#
# ###### END -> DOMAIN: Pháp luật, ALGORITHM: mean_shift <- ######
#
#
#
#
# ###### START -> DOMAIN: Pháp luật, ALGORITHM: dbscan <- ######
# Total labels: 7, Total docs: 184
# Label 0 has 2 articles
# title: Cô gái nghi bị người yêu đâm chết vì đòi về quê
# title: Cô gái bị người yêu đâm chết ở phòng trọ khi đòi về quê
#
#
# Label 1 has 2 articles
# title: Nghi can sát hại 3 người thân ở Sài Gòn vì 'mẹ mắng'
# title: Gia đình ở Sài Gòn giấu hết dao trước khi 3 người bị sát hại
#
#
# Label 2 has 2 articles
# title: Tạm giữ 9 đối tượng trong vụ bắn người tại trường gà
# title: Truy bắt nhóm đối tượng bắn người tại trường gà
#
#
# Label 3 has 2 articles
# title: Bị đánh toác đầu vì nói chủ quán nước 'chặt chém'
# title: Quán nước đánh khách ở Long An bị đập phá
#
#
# ###### END -> DOMAIN: Pháp luật, ALGORITHM: dbscan <- ######
#
#
#
#
# ###### START -> DOMAIN: Khoa học, ALGORITHM: mean_shift <- ######
# Total labels: 66, Total docs: 66
# Label 55 has 1 articles
# title: Đàn cá voi sát thủ hợp sức giết mẹ con cá voi xám
#
#
# Label 44 has 1 articles
# title: Lính cứu hỏa Thái Lan hướng dẫn bắt rắn hổ mang bằng tay không
#
#
# Label 59 has 1 articles
# title: Rắn vùng vẫy cố thoát khỏi hàm răng cá sấu
#
#
# Label 43 has 1 articles
# title: Chiếc bẫy tử thần của kiến sư tử
#
#
# Label 23 has 1 articles
# title: Tại sao chim yến ngủ và giao phối khi bay?
#
#
# ###### END -> DOMAIN: Khoa học, ALGORITHM: mean_shift <- ######
#
#
#
#
# ###### START -> DOMAIN: Khoa học, ALGORITHM: dbscan <- ######
# Total labels: 1, Total docs: 66
# ###### END -> DOMAIN: Khoa học, ALGORITHM: dbscan <- ######
#
#
#
#
# ###### START -> DOMAIN: all, ALGORITHM: mean_shift <- ######
# Total labels: 1271, Total docs: 1291
# Label 0 has 10 articles
# title: Đáp án câu 3
# title: Đáp án câu 2
# title: Đáp án câu 3
# title: Đáp án câu 1
# title: Đáp án câu 5
# title: Đáp án câu 2
# title: Đáp án câu 4
# title: Đáp án câu 4
# title: Năm câu đố tìm sự khác biệt
# title: Đáp án câu 1
#
#
# Label 1 has 4 articles
# title: Đáp án câu 3
# title: Đáp án câu 4
# title: Đáp án câu 1
# title: Đáp án câu 2
#
#
# Label 2 has 3 articles
# title: Phần 2
# title: Đáp án phần 2
# title: Đáp án phần 1
#
#
# Label 6 has 2 articles
# title: Chính xác, ông là Michael Faraday
# title: Chưa chính xác, ông là Michael Faraday
#
#
# Label 5 has 2 articles
# title: Chưa chính xác, ông đã tìm ra hợp chất benzene
# title: Chính xác, ông đã tìm ra hợp chất benzene
#
#
# ###### END -> DOMAIN: all, ALGORITHM: mean_shift <- ######
#
#
#
#
# ###### START -> DOMAIN: all, ALGORITHM: dbscan <- ######
# Total labels: 36, Total docs: 1291
# Label 2 has 265 articles
# title: Chính xác, ông là Michael Faraday
# title: Đáp án câu 3
# title: Đáp án câu 2
# title: Đáp án câu 3
# title: Đáp án câu 3
# title: Đáp án câu 1
# title: Thử tài giải năm câu đố tìm số
# title: Rèn luyện trí não với bốn câu đố cuối tuần
# title: Đáp án câu 4
# title: Đáp án câu 1
# title: Phần 2
# title: Chưa chính xác, ông là Michael Faraday
# title: Đáp án câu 5
# title: Chưa chính xác, ông đã tìm ra hợp chất benzene
# title: Đáp án câu 2
# title: Đáp án câu 4
# title: Đáp án câu 4
# title: Đáp án phần 2
# title: Thiên tài khoa học nào từng là cậu bé đóng sách?
# title: Năm câu đố tìm sự khác biệt
# title: Đáp án phần 1
# title: Học tiếng Anh: Bài phát biểu của nữ sinh được đề cử Nobel Hòa Bình
# title: Đáp án câu 2
# title: Bốn câu đố đo tư duy logic của bạn
# title: Chính xác, ông đã tìm ra hợp chất benzene
# title: Đáp án câu 1
# title: Nhóm “cẩu tặc” chạy tán loạn trong đêm khi bị vây bắt
# title: Tài xế “rút ruột” hàng của công ty đem bán
# title: Vụ án mạng tại trường học ở Thanh Hóa: Hung thủ âm tính với ma túy
# title: Bị đánh toác đầu vì nói chủ quán nước 'chặt chém'
# title: Sau 2 năm, băng trộm 8,6 tỉ ở Thủ Đức bị bắt giữ
# title: Đối tượng đổ xăng phóng hỏa cửa hàng quần áo trẻ em bị bắt giữ
# title: 2 người đàn ông bất động trong phòng trọ, người đầy máu
# title: Án mạng trong phòng trọ ven Sài Gòn
# title: 4 người trộm vịt thoát tội, gia chủ bị truy tố
# title: Quán nước đánh khách ở Long An bị đập phá
# title: Hai nhóm thanh niên hỗn chiến vì tranh giành nữ tiếp viên quán bar
# title: Barcelona nhận tin dữ trước thềm trận chiến gặp Liverpool
# title: Những khoảnh khắc tệ hại của Man Utd trước Huddersfield
# title: Gary Neville: “MU là tập thể của những con người hèn kém”
# title: Arsenal thắng cách biệt hai bàn ở lượt đi bán kết Europa League
# title: Solskjaer trách móc hàng tiền đạo của Man Utd
# title: Solskjaer: 'Không bất ngờ khi Man Utd rớt khỏi top 4'
# title: Gary Neville: 'Tôi thích xem Huddersfield đá hơn Man Utd'
# title: Ajax đoạt danh hiệu đầu tiên, hướng đến cú ăn ba
# title: Chiellini: 'Messi và Ronado như Federer - Nadal của quần vợt'
# title: Klopp: 'Trái tim giúp Liverpool chiến thắng'
# title: Tháng Ramadan đe dọa cơ hội 'ăn ba' của Ajax
# title: Ronaldo: 'Nhiều người chờ đợi tôi đá hỏng phạt đền hoặc gục ngã'
# title: Federer chung nhánh Djokovic ở Madrid Mở rộng 2019
# title: Liverpool thảm bại trước Barcelona, HLV Jurgen Klopp quyết vô địch Premier League
# title: Vắng Messi và Suarez, Barcelona gục ngã trước Celta Vigo
# title: Barcelona - Liverpool: Cuộc chiến khó lường
# title: HLV Barcelona choáng vì siêu phẩm của Messi
# title: Ramsey gửi tâm thư “đầy nước mắt” chia tay người hâm mộ Arsenal
# title: Emery vô tình làm lộ chiến thuật của Arsenal tại Europa League
# title: HAGL - Nam Định: HLV Lee Tae-hoon tìm thắng lợi đầu tay
# title: Ngoại binh khen Quang Hải chơi đồng đội
# title: HLV Klopp chưa từng thắng ở Tây Ban Nha
# title: Quang Hải giúp Hà Nội thắng đậm tại AFC Cup
# title: Bác sỹ tim mạch lo Casillas phải giải nghệ
# title: Ramsey rơi nước mắt trong ngày chia tay Arsenal
# title: Man City - Leicester: Chạm tay vào ngôi báu
# title: Kompany bực vì đồng đội khuyên đừng sút trong pha ghi bàn
# title: McManaman: 'Alisson Becker đã không tuân lệnh Klopp'
# title: Cầu thủ B.Bình Dương chấn thương nặng được trọng tài cấp cứu ngay trên sân
# title: Ten Hag: 'Ajax đã chiến đấu như những chú sư tử'
# title: Hàng loạt ngôi sao Man Utd bị giảm lương vì không vào top 4
# title: Real thắng trận sân nhà thứ năm liên tiếp ở La Liga
# title: MU thét giá trên trời cho Paul Pogba
# title: HLV Mourinho: “Messi là vị Chúa của bóng đá”
# title: Jurgen Klopp: “Liverpool sẽ dập tắt giấc mơ của Messi”
# title: Barcelona sẽ thăng hoa nhờ lối chơi thực dụng?
# title: Tottenham 0-1 Ajax: Pha làm bàn của Van de Beek
# title: HLV Mourinho bất ngờ lên tiếng trách móc MU
# title: Messi lập cú đúp giúp Barca thắng Liverpool 3-0
# title: Thủ quân Liverpool chờ phép màu cản bước Man City
# title: Cựu tiền đạo Liverpool: 'Suarez hành động như một con chuột'
# title: Barcelona 3-0 Liverpool: Cú đúp của Messi
# title: Barca thất bại lần đầu sau nửa năm ở La Liga
# title: HLV Jurgen Klopp cảm thấy “tâm phục, khẩu phục” trước Messi
# title: Nou Camp lập kỷ lục về khán giả ở trận Barca - Liverpool
# title: HLV Valverde nhắc lại trận thua Roma để cảnh tỉnh Barca
# title: Van Dijk bị nghi cầu cứu đồng đội khi đối đầu Messi
# title: Alexander-Arnold: 'Mọi chuyện đều có thể xảy ra tại Anfield'
# title: Chủ tịch Napoli: 'Nên đập bỏ Champions League và Europa League'
# title: Nhìn lại trận hòa cay đắng của Arsenal trước Brighton
# title: Cận cảnh cuộc sống hạnh phúc với vợ đẹp, con thơ của C.Ronaldo
# title: Man Utd hết cửa vào top 4 Ngoại hạng Anh
# title: McIlroy giữ đỉnh bảng vòng một Wells Fargo
# title: Chelsea - Watford: Thời cơ cho Chelsea vào top 3
# title: Bournemouth 1-0 Tottenham: Son Heung Min bị đuổi, bàn thua phút bù giờ
# title: Messi thừa nhận 'ăn may' với cú sút phạt vào lưới Liverpool
# title: Aubameyang quyết tâm giành danh hiệu Vua phá lưới Premier League
# title: Messi nói gì sau khi chạm mốc 600 bàn thắng cho Barcelona?
# title: HLV Tottenham nói gì sau thất bại cay đắng trước Ajax?
# title: Giá trị của Quế Ngọc Hải trong ngày trở lại
# title: Sự khác biệt giữa “hai người cũ” của Liverpool trong màu áo Barcelona
# title: Ajax phớt lờ Tottenham, tập trung giành Cup Hà Lan
# title: Barca chưa từng bị loại khi thắng 3-0 ở lượt đi các Cup châu Âu
# title: Rakitic: 'Messi nói gì chúng tôi cũng nghe'
# title: Casillas bị trụy tim trên sân tập
# title: Guardiola: 'Liverpool không sụp đổ vì thua Barca'
# title: Klopp văng tục khi nhắc đến bàn thắng của học trò
# title: Nadal bỏ tập trước thềm Madrid Mở rộng vì dính virus
# title: Cựu Chủ tịch khuyên Man Utd bỏ thêm một mùa giải
# title: Chặng 3 Sơn La - Điện Biên, áo vàng đã đổi chủ
# title: Chelsea 3-0 Watford: The Blues vào top 3
# title: Sarri nhận sai khi để Kante thi đấu
# title: Liverpool hạ Newcastle để lên đỉnh bảng
# title: HLV Park sang Na Uy, theo dõi tiền đạo Việt kiều
# title: Mourinho đá xoáy Neville và Scholes
# title: HLV Juventus: 'Ajax quá may ở Champions League'
# title: Newcastle 2-3 Liverpool: Chiến thắng khó khăn
# title: HLV Ajax: “Chúng tôi đã chiến đấu như sư tử”
# title: B.Bình Dương phải thắng để duy trì hy vọng vào vòng knock-out AFC Cup
# title: Arsenal - Valencia: “Pháo thủ” có qua được khủng hoảng?
# title: Salah có nguy cơ lỡ trận bán kết lượt về gặp Barca
# title: Pochettino thừa nhận sai lầm dẫn tới trận thua Ajax
# title: 76ers nắm lợi thế tại bán kết play-off miền Đông NBA
# title: Thủ quân Ajax tiếc vì không thể thắng Tottenham đậm hơn
# title: Klopp xem thường sức nóng của Nou Camp
# title: Chờ "derby London" ở chung kết Europa League
# title: Salah phải nghỉ trận bán kết lượt về với Barca
# title: Huddersfield 1-1 Man Utd: “Quỷ đỏ” hết cơ hội vào top 4
# title: Thái Lan tìm HLV mới sau King's Cup
# title: Emery: 'Arsenal cần quên Ngoại hạng Anh, tập trung cho Europa League'
# title: Viettel chia điểm với SLNA
# title: Hai hậu vệ Liverpool lập kỷ lục kiến tạo
# title: Các ông chủ Qatar tính phương án bán PSG
# title: Anh Đức ghi bàn, B.Bình Dương nuôi hy vọng đi tiếp tại AFC Cup
# title: Alba: 'Barca sẽ rất nhớ Messi một khi anh ấy giải nghệ'
# title: Barca - Liverpool: Chờ bữa tiệc bóng đá tấn công
# title: Bình Dương đè bẹp Persija Jakarta ở AFC Cup
# title: Man City đảm bảo tương lai cho Mendy
# title: Ngoại hạng Anh xác định xong ba đội xuống hạng
# title: Casillas xuất viện sau ca cấp cứu vì bị trụy tim
# title: Võ sĩ Việt huỷ thi đấu với cao thủ Vịnh Xuân Flores
# title: Arsenal 1-1 Brighton: Trận hòa cay đắng với "Pháo thủ"
# title: Những khoảnh khắc Messi nhấn chìm Liverpool tại Nou Camp
# title: Max Homa vô địch giải Wells Fargo
# title: Canelo thống nhất đai vô địch hạng trung nhờ tính điểm
# title: Mourinho: 'Messi là Chúa tể bóng đá'
# title: Barca từng hai lần vô địch sau khi Messi lập cú đúp ở bán kết
# title: Thắng đậm đại diện Campuchia, Hà Nội FC sáng cửa đi tiếp ở AFC Cup
# title: Liverpool đối đầu với Barcelona: Trông vào “bức tường thành”
# title: Vertonghen đổ máu trong ngày Tottenham bại trận trước Ajax
# title: Messi ăn vạ trước khi lập siêu phẩm vào lưới Liverpool?
# title: Ba nguyên nhân khiến Liverpool thua cay đắng trên sân Barcelona
# title: Báo chí thế giới ngả mũ trước “thiên tài” Lionel Messi
# title: Guardiola: 'Liverpool là đối thủ khó chơi nhất sự nghiệp'
# title: Allegri: 'Ronaldo sẽ bùng nổ sau khi Messi ghi bàn thứ 600'
# title: Eriksen: 'Tottenham giúp Ajax chơi hay hơn'
# title: Klopp: 'Nếu muốn chiến thắng, bạn phải chấp nhận mình có thể thua'
# title: Arsenal xác nhận chia tay “chân gỗ” Welbeck
# title: Guardiola bất ngờ khi Man City có gần 100 điểm mùa này
# title: Guardiola: 'Liverpool không chịu áp lực vì chức vô địch nằm trong tay Man City'
# title: Flores bức xúc vì bị võ sĩ Việt huỷ đấu
# title: Chủ tịch Barca: 'Sẽ có 10 bức tượng Messi ở sân Nou Camp'
# title: Nadal: ‘Sự tự tin của tôi đã trở lại’
# title: Cầu thủ Bình Dương bị chấn động não, lún thái dương
# title: Chelsea giành lợi thế sau lượt đi bán kết Europa League
# title: Semenya: 'Không ai có thể bắt tôi ngừng chạy'
# title: CĐV Việt Nam vẫn mong chờ chung kết toàn Anh ở Champions League
# title: HLV Lee Tae-hoon giành chiến thắng đầu tiên cùng HAGL
# title: Van Dijk: 'Thật dễ chịu khi không phải gặp Messi mỗi mùa'
# title: C.Ronaldo lại sắm vai người hùng giúp Juventus thoát thua
# title: Newcastle - Liverpool: Nỗi niềm khó nói của Rafa Benitez
# title: Liverpool đón trụ cột trở lại ở đại chiến với Barcelona
# title: Đội tuyển Việt Nam khủng hoảng trung phong: Thầy Park nhắm đến Alexander Đặng?
# title: Chấm điểm trận Barcelona đại thắng Liverpool: Messi đạt điểm 10
# title: Arsenal 3-1 Valencia: Cú đúp của Lacazette
# title: Hòa trên sân Frankfurt, Chelsea giành lợi thế ở bán kết Europa League
# title: Rio Ferdinand, Luis Figo đến Việt Nam trong tháng Sáu
# title: Tiger Woods vẫn chưa trở lại thi đấu sau Masters
# title: Barca bắt kịp cột mốc ghi bàn của Real tại Champions League
# title: Klopp: 'Liverpool đã chơi trận sân khách hay nhất ở Champions League'
# title: Ajax “bơi trong tiền” nếu như lọt vào chung kết Champions League
# title: Chelsea lấy vị trí thứ ba của Tottenham
# title: Arsenal cạn hy vọng top 4 Ngoại hạng Anh
# title: Báo Anh ám chỉ Messi gian lận khi phá lưới Liverpool
# title: Dominic Thiem: 'Roland Garros là mục tiêu của đời tôi'
# title: Messi chạm mốc 600 bàn cho Barca
# title: Iker Casillas nhập viện khẩn cấp do đau tim
# title: Chelsea và liều thuốc thử hạng nặng ở bán kết Europa League
# title: Newcastle - Liverpool: Gượng dậy sau thảm bại
# title: Wenger: 'Messi là nguyên nhân khiến Liverpool sụp đổ trước Barca'
# title: Messi chỉ trích CĐV nhà khi la ó Coutinho
# title: 'Suarez tái ngộ để cắn Liverpool'
# title: Truyền thông Anh ngả mũ trước Messi
# title: Tottenham bại trận sau khi bị đuổi hai người
# title: Xavi giải nghệ, chuẩn bị làm HLV
# title: Chelsea chắc chỗ trong top 4 Ngoại hạng Anh
# title: Ronaldo lại vượt Messi sau khi chạm mốc 600 bàn
# title: Hàng nghìn CĐV kiến nghị UEFA phạt nguội Messi
# title: Bayern nới khoảng cách với Dortmund lên 5 điểm
# title: Wimbledon công bố mức tiền thưởng kỷ lục
# title: Những điểm nhấn trước cuộc đối đầu kinh điển Barcelona - Liverpool
# title: Danh thủ Xavi giã từ sự nghiệp ở tuổi 39
# title: C.Ronaldo, Messi cán mốc 600 bàn thắng diễn ra như thế nào?
# title: Van Dijk thừa nhận nỗi ám ảnh về Messi
# title: Lionel Messi: Người khổng lồ trong khuôn hình tí hon
# title: Man Utd sẵn sàng mất tiền để tống khứ Sanchez
# title: Barca cho hàng loạt trụ cột dưỡng sức, chờ tái đấu Liverpool
# title: Chelsea khủng hoảng hàng thủ ở bán kết lượt đi Europa League
# title: Pochettino lấy Messi làm gương cho học trò
# title: Man City đòi lại ngôi đầu sau trận thắng tối thiểu Leicester
# title: Klopp: 'Liverpool sẽ thử ghi bốn bàn vào lưới Barca'
# title: Người dân "tay xách nách mang" trở lại Thủ đô sau nghỉ lễ
# title: Đại tướng Lê Đức Anh và những phút sinh tử trên trận mạc
# title: Chiến sỹ Điện Biên kể chuyện
# title: Tăng giá điện 2019: Hãy là người tiêu dùng thông minh
# title: Cảng cá vừa nạo vét đã bị bồi lấp trở lại, ngư dân khóc ròng
# title: Hà Nội: Bắt xe khách 29 chỗ nhồi… 73 người
# title: “Ông chủ” doanh nghiệp thủy sản trúng số độc đắc gần 120 tỷ đồng
# title: Doanh nghiệp Việt rộng cửa nhờ CPTPP
# title: Bình quân mỗi tháng Honda Việt Nam thu hơn 7.600 tỷ
# title: Đại gia ngoại dòm ngó "cỗ máy in tiền" số 1 Việt Nam
# title: Công ty của Warren Buffett mua cổ phiếu Amazon
# title: Chủ doanh nghiệp thủy sản Cà Mau trúng xổ số gần 120 tỷ đồng
# title: VietinBank tuyển hơn 300 nhân sự trên toàn hệ thống
# title: 70% cổ phiếu giảm, VN-Index mất hơn 17 điểm
# title: Vingroup đã đầu tư gần 31.000 tỷ đồng vào VinFast
# title: Lãi ròng SBT tăng hơn gấp đôi cùng kỳ
# title: Bàn tay vàng của Warren Buffett liệu đã hết phép?
# title: Thị trường vàng trang sức 2019: Bứt phá từ động lực tăng trưởng
# title: Tái hiện “một Amalfi” bên bờ biển Nam Phú Quốc
# title: VietinBank đẩy mạnh số hóa hệ sinh thái ngân hàng
# title: Giá dầu giảm vì Mỹ sản xuất kỷ lục
# title: Giao dịch trực tuyến của VietinBank gia tăng nhờ CoreBanking
# title: Cơ hội kết nối 1-1 với đối tác ngoại sáng 3/5 tại Diễn đàn Kinh tế tư nhân
# title: Những bật mí của vị chủ tịch "triệu đô" không sở hữu chiếc xe nào
# title: Mỹ để ngỏ khả năng can thiệp quân sự vào Venezuela sau đảo chính bất thành
# title: Thủ lĩnh đối lập Venezuela lý giải việc đảo chính thất bại
# title: Ông Trump úp mở về kế hoạch lớn ở Venezuela vào tuần tới
# title: Nga cảnh báo hậu quả nếu Mỹ không từ bỏ ý định lật đổ Tổng thống Venezuela
# title: Nga - Mỹ quyết "so găng" ở Venezuela
# title: Đánh chìm tàu sân bay Mỹ: Nói dễ hơn làm
# title: Tên lửa Triều Tiên không vươn tới vùng đặc quyền kinh tế Nhật Bản
# title: Ấn Độ: 19 học sinh tự tử vì bị "chấm điểm sai"
# title: Bức ảnh "triệu tấm có một" trong vụ thử tên lửa Triều Tiên
# title: Câu hỏi bỏ ngỏ sau đảo chính thất bại ở Venezuela
# title: Venezuela ra trát bắt giữ thủ lĩnh tinh thần của phe đối lập sau đảo chính bất thành
# title: Khoảnh khắc máy bay Nga chở 78 người lao xuống đường băng, bốc cháy
# title: Hành khách kể giây phút máy bay Mỹ chở 143 người lao xuống sông
# title: Bên trong máy bay Nga cháy ngùn ngụt khi hạ cánh
# title: Tổng thống Venezuela kêu gọi đối thoại để "sửa chữa sai lầm"
# title: Ông Trump phàn nàn bị "lấy mất" 2 năm nhiệm kỳ
# title: Chuyên gia “giải mã” vụ phóng tên lửa mới của Triều Tiên
# title: Mỹ đưa tàu sân bay, máy bay ném bom đến Trung Đông
# title: Nhân chứng vụ rơi máy bay Nga: Máy bay cháy rực như ngọn đuốc
# title: Giới an ninh, quân sự Mỹ họp khẩn về phương án ở Venezuela
# title: Máy bay Mỹ chở 143 người lao xuống sông trong đêm
# title: Đảo chính Venezuela: “Vết rạn” mới trong quan hệ Nga-Mỹ
# title: Cánh cửa hẹp cho phe đối lập sau đảo chính bất thành tại Venezuela
# title: Nga cảnh báo hậu quả nặng nề nếu Mỹ tiếp tục can thiệp vào Venezuela
# title: Triều Tiên bất ngờ phóng tên lửa tầm ngắn
# title: Nga lên kế hoạch ngăn Mỹ can thiệp quân sự vào Venezuela
# title: Phản ứng trái chiều của các nước về đảo chính Venezuela
# title: Ngoại trưởng Pompeo: "Mọi hành động của Mỹ ở Venezuela đều hợp pháp"
# title: “Dấu chân” của Mỹ trong kế hoạch đảo chính bất thành tại Venezuela
# title: Rơi trực thăng quân sự Venezuela, 7 người thiệt mạng
# title: Lộ kế hoạch 5.000 lính đánh thuê lật đổ ông Maduro
# title: Cựu binh Pháp chia sẻ về ký ức Điện Biên Phủ
# title: Maduro tổ chức 'ngày đối thoại' để sửa chữa sai lầm
#
#
# Label 22 has 16 articles
# title: Những con số choáng ngợp về lễ đăng cơ của Quốc vương Thái Lan
# title: Sứ mệnh lớn lao của tân Quốc vương Thái Lan
# title: Vai trò biểu tượng quốc gia của Vua Thái Lan
# title: 300 UAV trình diễn ánh sáng mừng Quốc vương Thái Lan đăng quang
# title: Quốc vương Thái Lan ngồi kiệu dát vàng 16 người khiêng trong lễ rước đăng quang
# title: Voi quý được coi là biểu tượng cho quyền uy của quốc vương Thái Lan
# title: Quốc vương Thái Lan ban danh hiệu mới cho thành viên hoàng gia
# title: Quốc vương Thái Lan tuyên bố trị vì bằng chính nghĩa ngay sau đăng quang
# title: Quốc vương Thái Lan bái Phật trước khi đăng quang
# title: Quốc vương Thái Lan kết hôn với nữ tướng ngay trước lễ đăng cơ
# title: Thái Lan rước bảo vật hoàng gia trước lễ đăng quang của tân vương
# title: 5 báu vật hoàng gia được trao trong lễ đăng cơ của Quốc vương Thái Lan
# title: Quốc vương Thái Lan kết hôn với nữ tướng
# title: Quốc vương Thái Lan kêu gọi người dân đoàn kết sau khi đăng quang
# title: Các nghi thức trong lễ đăng quang của tân vương Thái Lan
# title: Quốc vương Thái Lan đội vương miện hơn 7kg, chính thức đăng quang
#
#
# Label 9 has 8 articles
# title: HLV Park Hang Seo chốt ngày sang châu Âu “xem giò” cầu thủ Việt kiều
# title: Alexander Đặng mờ nhạt trong ngày HLV Park Hang Seo “xem giò”
# title: HLV Park Hang Seo tiết lộ danh sách cầu thủ Việt kiều trong tầm ngắm
# title: Người đại diện Alexander Đặng sẵn sàng làm tài xế cho HLV Park Hang Seo
# title: Filip Nguyễn hứa sẽ ghi điểm trong mắt HLV Park Hang Seo
# title: HLV Park Hang Seo sang châu Âu "xem giò" cầu thủ Việt kiều
# title: HLV Park Hang Seo bất ngờ huỷ kế hoạch gặp Filip Nguyễn
# title: Alexander Đặng khó lọt vào mắt xanh của HLV Park Hang Seo
#
#
# Label 16 has 6 articles
# title: Thủ tướng chỉ đạo làm rõ việc tăng giá điện
# title: Bộ Công Thương sẽ kiểm tra tác động tăng giá điện
# title: Bộ Công Thương lập 3 đoàn kiểm tra liên quan đến việc tăng giá điện
# title: Phó thủ tướng yêu cầu tiếp tục theo dõi tác động tăng giá điện
# title: Thủ tướng yêu cầu kiểm tra lại việc đúng sai trong tăng giá điện
# title: Phó thủ tướng yêu cầu đánh giá tác động của việc tăng giá điện
#
#
# ###### END -> DOMAIN: all, ALGORITHM: dbscan <- ######
